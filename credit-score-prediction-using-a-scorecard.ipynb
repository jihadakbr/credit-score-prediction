# %% [markdown]
# <h1 align="center">Credit Score Prediction Using a Scorecard - Home Credit Indonesia</h1>

# %% [markdown]
# ###### By: [jihad akbar](https://github.com/jihadakbr) | Dataset: Home Credit Indonesia's internal database
# ###### You can see this notebook clearly using this link [nbviewer.org](https://nbviewer.org/github/jihadakbr/credit-score-prediction/blob/main/credit-score-prediction-using-a-scorecard.ipynb).

# %% [markdown]
# <div id="toc"><h1>Table of Contents</h1></div>
#
# <div id="backTotop" class="alert alert-block alert-info">
#     <ol>
#         <li><a href="#one">Problem Formulation</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>1.1 <a href="#problem">Business Understanding</a></li>
#                 <li>1.2 <a href="#prompt">Project Prompt</a></li>
#                 <li>1.3 <a href="#tools">Selecting Appropriate Tools</a></li>
#                 <li>1.4 <a href="#timeline">Determining the Data Science Project Workflow and Timeline</a></li>
#             </ol>
#         </li>
#         <li><a href="#two">Data Collecting</a></li>
#         <li><a href="#three">Data Understanding</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>3.1 <a href="#datasetcontent">Reviewing the Dataset's Content</a></li>
#             </ol>
#         </li>
#         <li><a href="#four">Data preprocessing</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>4.1 <a href="#libraries">Importing Required Libraries</a></li>
#                 <li>4.2 <a href="#reading">Importing and Reading the File</a></li>
#                 <li>4.3 <a href="#rowscolumns">Determining the Number of Rows and Columns</a></li>
#                 <li>4.4 <a href="#pythondropcols">Dropping Unnecessary Columns and Removing > 70% Missing Values</a></li>
#                 <li>4.5 <a href="#dupvalues">Removing Duplicated Values</a></li>
#                 <li>4.6 <a href="#splittingtraintest">Splitting the Dataset into Training and Test Sets</a></li>
#                 <li>4.7 <a href="#convdatatypes">Converting Data Types</a></li>
#                 <li>4.8 <a href="#pythonaddcols">Creating New Features</a></li>
#                 <li>4.9 <a href="#outliers">Detecting and Handling Outliers</a></li>
#                 <li>4.10 <a href="#dropsavecols">Dropping and Saving Columns</a></li>
#             </ol>
#         </li>
#         <li><a href="#five">Exploratory Data Analysis (EDA) and Data Visualization</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>5.1 <a href="#edadist">Analyzing Numerical Distribution</a></li>
#                 <li>5.2 <a href="#edaplothist">Plotting Histograms of Selected Categorical Variables to Target Variable</a></li>
#                 <li>5.3 <a href="#edatarvarpro">Checking Target Variable Proportions</a></li>
#             </ol>
#         </li>
#         <li><a href="#six">Feature Selection and Engineering</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>6.1 <a href="#utilchisquare">Chi Square Test (Categorical Features)</a></li>
#                 <li>6.2 <a href="#anovaa">ANOVA (Numerical Features)</a></li>
#                 <li>6.3 <a href="#cormatrix">Correlation Matrix</a></li>
#                 <li>6.4 <a href="#dummyencod">Dummy Encoding</a></li>
#                 <li>6.5 <a href="#woeandiv">Weight of Evidence (WOE) and Information Value (IV)</a>
#                     <ol style="list-style-type:none;padding-left:1.75em">
#                         <li>6.5.1 <a href="#discfeature">Discrete Features</a></li>
#                         <li>6.5.2 <a href="#numcfeature">Numeric Features</a></li>
#                     </ol>
#                 </li>
#             </ol>
#         </li>
#         <li><a href="#seven">Model Selection and Building</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>7.1 <a href="#trainml">Training the Machine Learning Model</a></li>
#                 <li>7.2 <a href="#testml">Testing the Machine Learning Model</a></li>
#                 <li>7.3 <a href="#confmatrixauroctest">Confusion Matrix and AUROC on Test Set</a></li>
#             </ol>
#         </li>
#         <li><a href="#eight">Scorecard Development</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>8.1 <a href="#scorecardcreate">Creating a Scorecard</a></li>
#                 <li>8.2 <a href="#calcreditscores">Calculating credit scores in the X_test set</a></li>
#                 <li>8.3 <a href="#loancutoffs">Setting loan approval cut-offs</a></li>
#                 <li>8.4 <a href="#calcreditscorestest">Calculating credit scores in the X_test set with the best threshold</a></li>
#                 <li>8.5 <a href="#testsubmncalcredscores">Calculating credit scores in the test_subm set with the best threshold</a></li>
#             </ol>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# <div id="one">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">1. Problem Formulation</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="problem">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.1 Business Understanding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# **Home Credit Indonesia** is currently using various statistical methods and Machine Learning to make **credit score predictions**. Now, we ask you to unlock the maximum potential of our data. By doing so, we can ensure that:
# 1. Customers who are capable of repayment are not rejected when applying for a loan.
# 2. Loans can be given with a principal, maturity, and repayment calendar that will motivate customers to succeed.
#
# Evaluation will be done by checking how deep your understanding of the analysis is. Note that you need to use at least Logistic Regression to construct your machine learning models. After that, create a presentation slide containing end-to-end modeling analysis results along with business recommendations (maximum 10 pages).

# %% [markdown]
# <div id="prompt">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.2 Project Prompt</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# 1. Downloading the required dataset.
# 2. Learning the problem context from external sources to improve Subject Matter Knowledge.
# 3. Understanding the available column descriptions.
# 4. Determining the goals, objectives, and metrics of the existing problem.
# 5. Performing information mining related to the initial data condition.
# 6. Carrying out the Data Cleaning and Data Processing processes.
# 7. Performing the insight mining process referring to the established objectives.
# 8. Performing modeling using various methods (including Logistic Regression) and its hyperparameters.
# 9. Evaluating the modeling results.
# 10. Measuring the impact of modeling and business recommendations on the previously established metrics.
# 11. Pushing your .ipynb file to Github.
# 12. Creating a presentation file to explain the work that has been done and including the Github repo link in the presentation.

# %% [markdown]
# <div id="tools">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.3 Selecting Appropriate Tools</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# * Programming language: Python.
# * Data Tool: Jupyter Notebook.
# * Reporting Tool: Microsoft PowerPoint.

# %% [markdown]
# <div id="timeline">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.4 Determining the Data Science Project Workflow and Timeline</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# Deadline: 14th May 2023 (a 1-month project)
#
# | No. | Workflow | Weight |
# |:---|:---|---|
# | 1 | Problem Formulation | 5% |
# | 2 | Data Collecting | 5% |
# | 3 | Data Understanding | 5% |
# | 4 | Data preprocessing | 20% |
# | 5 | Exploratory Data Analysis (EDA) and Data Visualization | 5% |
# | 6 | Feature Selection and Engineering | 30% |
# | 7 | Model Selection and Building | 15% |
# | 8 | Scorecard Development | 15% |

# %% [markdown]
# <div id="two">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">2. Data Collecting</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# The Home Credit Indonesia has provided the dataset from its internal database.

# %% [markdown]
# <div id="three">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">3. Data Understanding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="datasetcontent">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">3.1 Reviewing the Dataset's Content</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# I received a total of 10 .csv files, which are named as follows:
# 1. application_test.csv
# 2. application_train.csv
# 3. bureau.csv
# 4. bureau_balance.csv
# 5. credit_card_balance.csv
# 6. HomeCredit_columns_description.csv
# 7. installments_payments.csv
# 8. POS_CASH_balance.csv
# 9. previous_application.csv
# 10. sample_submission.csv

# %% [markdown]
# The main table is contained in application_{train|test}.csv, which has been split into two files for Train (with TARGET) and Test (without TARGET).

# %% [markdown]
# Because my laptop has limited specifications, specifically only 4 GB of RAM, I am only able to handle two out of eight .csv files, excluding the files named "HomeCredit_columns_description.csv" and "sample_submission.csv." When I attempted to merge six files into the "application_test.csv" and "application_train.csv" files, my laptop crashed.

# %% [markdown]
# It's important to merge the six files into the "application_test.csv" and "application_train.csv" before beginning data processing, in order to avoid any potential data leakage.

# %% [markdown]
# The column description for the "application_test.csv" and "application_train.csv" files is provided below:
#
# <details>
#     <summary><code>Click here to show hidden text</code></summary>
#
#   | No. | Row | Description |
# |:-:|:--|:--|
# |	1	|	SK&#95;ID&#95;CURR	|	ID of loan in our sample	|
# |	2	|	TARGET	|	Target variable (0 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 1 - all other cases)	|
# |	3	|	NAME&#95;CONTRACT&#95;TYPE	|	Identification if loan is cash or revolving	|
# |	4	|	CODE&#95;GENDER	|	Gender of the client	|
# |	5	|	FLAG&#95;OWN&#95;CAR	|	Flag if the client owns a car	|
# |	6	|	FLAG&#95;OWN&#95;REALTY	|	Flag if client owns a house or flat	|
# |	7	|	CNT&#95;CHILDREN	|	Number of children the client has	|
# |	8	|	AMT&#95;INCOME&#95;TOTAL	|	Income of the client	|
# |	9	|	AMT&#95;CREDIT	|	Credit amount of the loan	|
# |	10	|	AMT&#95;ANNUITY	|	Loan annuity	|
# |	11	|	AMT&#95;GOODS&#95;PRICE	|	For consumer loans it is the price of the goods for which the loan is given	|
# |	12	|	NAME&#95;TYPE&#95;SUITE	|	Who was accompanying client when he was applying for the loan	|
# |	13	|	NAME&#95;INCOME&#95;TYPE	|	Clients income type (businessman, working, maternity leave,…)	|
# |	14	|	NAME&#95;EDUCATION&#95;TYPE	|	Level of highest education the client achieved	|
# |	15	|	NAME&#95;FAMILY&#95;STATUS	|	Family status of the client	|
# |	16	|	NAME&#95;HOUSING&#95;TYPE	|	What is the housing situation of the client (renting, living with parents, ...)	|
# |	17	|	REGION&#95;POPULATION&#95;RELATIVE	|	Normalized population of region where client lives (higher number means the client lives in more populated region)	|
# |	18	|	DAYS&#95;BIRTH	|	Client's age in days at the time of application	|
# |	19	|	DAYS&#95;EMPLOYED	|	How many days before the application the person started current employment	|
# |	20	|	DAYS&#95;REGISTRATION	|	How many days before the application did client change his registration	|
# |	21	|	DAYS&#95;ID&#95;PUBLISH	|	How many days before the application did client change the identity document with which he applied for the loan	|
# |	22	|	OWN&#95;CAR&#95;AGE	|	Age of client's car	|
# |	23	|	FLAG&#95;MOBIL	|	Did client provide mobile phone (1=YES, 0=NO)	|
# |	24	|	FLAG&#95;EMP&#95;PHONE	|	Did client provide work phone (1=YES, 0=NO)	|
# |	25	|	FLAG&#95;WORK&#95;PHONE	|	Did client provide home phone (1=YES, 0=NO)	|
# |	26	|	FLAG&#95;CONT&#95;MOBILE	|	Was mobile phone reachable (1=YES, 0=NO)	|
# |	27	|	FLAG&#95;PHONE	|	Did client provide home phone (1=YES, 0=NO)	|
# |	28	|	FLAG&#95;EMAIL	|	Did client provide email (1=YES, 0=NO)	|
# |	29	|	OCCUPATION&#95;TYPE	|	What kind of occupation does the client have	|
# |	30	|	CNT&#95;FAM&#95;MEMBERS	|	How many family members does client have	|
# |	31	|	REGION&#95;RATING&#95;CLIENT	|	Our rating of the region where client lives (1,2,3)	|
# |	32	|	REGION&#95;RATING&#95;CLIENT&#95;W&#95;CITY	|	Our rating of the region where client lives with taking city into account (1,2,3)	|
# |	33	|	WEEKDAY&#95;APPR&#95;PROCESS&#95;START	|	On which day of the week did the client apply for the loan	|
# |	34	|	HOUR&#95;APPR&#95;PROCESS&#95;START	|	Approximately at what hour did the client apply for the loan	|
# |	35	|	REG&#95;REGION&#95;NOT&#95;LIVE&#95;REGION	|	Flag if client's permanent address does not match contact address (1=different, 0=same, at region level)	|
# |	36	|	REG&#95;REGION&#95;NOT&#95;WORK&#95;REGION	|	Flag if client's permanent address does not match work address (1=different, 0=same, at region level)	|
# |	37	|	LIVE&#95;REGION&#95;NOT&#95;WORK&#95;REGION	|	Flag if client's contact address does not match work address (1=different, 0=same, at region level)	|
# |	38	|	REG&#95;CITY&#95;NOT&#95;LIVE&#95;CITY	|	Flag if client's permanent address does not match contact address (1=different, 0=same, at city level)	|
# |	39	|	REG&#95;CITY&#95;NOT&#95;WORK&#95;CITY	|	Flag if client's permanent address does not match work address (1=different, 0=same, at city level)	|
# |	40	|	LIVE&#95;CITY&#95;NOT&#95;WORK&#95;CITY	|	Flag if client's contact address does not match work address (1=different, 0=same, at city level)	|
# |	41	|	ORGANIZATION&#95;TYPE	|	Type of organization where client works	|
# |	42	|	EXT&#95;SOURCE&#95;1	|	Normalized score from external data source	|
# |	43	|	EXT&#95;SOURCE&#95;2	|	Normalized score from external data source	|
# |	44	|	EXT&#95;SOURCE&#95;3	|	Normalized score from external data source	|
# |	45	|	APARTMENTS&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	46	|	BASEMENTAREA&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	47	|	YEARS&#95;BEGINEXPLUATATION&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	48	|	YEARS&#95;BUILD&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	49	|	COMMONAREA&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	50	|	ELEVATORS&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	51	|	ENTRANCES&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	52	|	FLOORSMAX&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	53	|	FLOORSMIN&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	54	|	LANDAREA&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	55	|	LIVINGAPARTMENTS&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	56	|	LIVINGAREA&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	57	|	NONLIVINGAPARTMENTS&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	58	|	NONLIVINGAREA&#95;AVG	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	59	|	APARTMENTS&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	60	|	BASEMENTAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	61	|	YEARS&#95;BEGINEXPLUATATION&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	62	|	YEARS&#95;BUILD&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	63	|	COMMONAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	64	|	ELEVATORS&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	65	|	ENTRANCES&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	66	|	FLOORSMAX&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	67	|	FLOORSMIN&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	68	|	LANDAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	69	|	LIVINGAPARTMENTS&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	70	|	LIVINGAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	71	|	NONLIVINGAPARTMENTS&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	72	|	NONLIVINGAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	73	|	APARTMENTS&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	74	|	BASEMENTAREA&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	75	|	YEARS&#95;BEGINEXPLUATATION&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	76	|	YEARS&#95;BUILD&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	77	|	COMMONAREA&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	78	|	ELEVATORS&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	79	|	ENTRANCES&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	80	|	FLOORSMAX&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	81	|	FLOORSMIN&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	82	|	LANDAREA&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	83	|	LIVINGAPARTMENTS&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	84	|	LIVINGAREA&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	85	|	NONLIVINGAPARTMENTS&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	86	|	NONLIVINGAREA&#95;MEDI	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	87	|	FONDKAPREMONT&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	88	|	HOUSETYPE&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	89	|	TOTALAREA&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	90	|	WALLSMATERIAL&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	91	|	EMERGENCYSTATE&#95;MODE	|	Normalized information about building where the client lives, What is average (&#95;AVG suffix), modus (&#95;MODE suffix), median (&#95;MEDI suffix) apartment size, common area, living area, age of building, number of elevators, number of entrances, state of the building, number of floor	|
# |	92	|	OBS&#95;30&#95;CNT&#95;SOCIAL&#95;CIRCLE	|	How many observation of client's social surroundings with observable 30 DPD (days past due) default	|
# |	93	|	DEF&#95;30&#95;CNT&#95;SOCIAL&#95;CIRCLE	|	How many observation of client's social surroundings defaulted on 30 DPD (days past due) 	|
# |	94	|	OBS&#95;60&#95;CNT&#95;SOCIAL&#95;CIRCLE	|	How many observation of client's social surroundings with observable 60 DPD (days past due) default	|
# |	95	|	DEF&#95;60&#95;CNT&#95;SOCIAL&#95;CIRCLE	|	How many observation of client's social surroundings defaulted on 60 (days past due) DPD	|
# |	96	|	DAYS&#95;LAST&#95;PHONE&#95;CHANGE	|	How many days before application did client change phone	|
# |	97	|	FLAG&#95;DOCUMENT&#95;2	|	Did client provide document 2	|
# |	98	|	FLAG&#95;DOCUMENT&#95;3	|	Did client provide document 3	|
# |	99	|	FLAG&#95;DOCUMENT&#95;4	|	Did client provide document 4	|
# |	100	|	FLAG&#95;DOCUMENT&#95;5	|	Did client provide document 5	|
# |	101	|	FLAG&#95;DOCUMENT&#95;6	|	Did client provide document 6	|
# |	102	|	FLAG&#95;DOCUMENT&#95;7	|	Did client provide document 7	|
# |	103	|	FLAG&#95;DOCUMENT&#95;8	|	Did client provide document 8	|
# |	104	|	FLAG&#95;DOCUMENT&#95;9	|	Did client provide document 9	|
# |	105	|	FLAG&#95;DOCUMENT&#95;10	|	Did client provide document 10	|
# |	106	|	FLAG&#95;DOCUMENT&#95;11	|	Did client provide document 11	|
# |	107	|	FLAG&#95;DOCUMENT&#95;12	|	Did client provide document 12	|
# |	108	|	FLAG&#95;DOCUMENT&#95;13	|	Did client provide document 13	|
# |	109	|	FLAG&#95;DOCUMENT&#95;14	|	Did client provide document 14	|
# |	110	|	FLAG&#95;DOCUMENT&#95;15	|	Did client provide document 15	|
# |	111	|	FLAG&#95;DOCUMENT&#95;16	|	Did client provide document 16	|
# |	112	|	FLAG&#95;DOCUMENT&#95;17	|	Did client provide document 17	|
# |	113	|	FLAG&#95;DOCUMENT&#95;18	|	Did client provide document 18	|
# |	114	|	FLAG&#95;DOCUMENT&#95;19	|	Did client provide document 19	|
# |	115	|	FLAG&#95;DOCUMENT&#95;20	|	Did client provide document 20	|
# |	116	|	FLAG&#95;DOCUMENT&#95;21	|	Did client provide document 21	|
# |	117	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;HOUR	|	Number of enquiries to Credit Bureau about the client one hour before application	|
# |	118	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;DAY	|	Number of enquiries to Credit Bureau about the client one day before application (excluding one hour before application)	|
# |	119	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;WEEK	|	Number of enquiries to Credit Bureau about the client one week before application (excluding one day before application)	|
# |	120	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;MON	|	Number of enquiries to Credit Bureau about the client one month before application (excluding one week before application)	|
# |	121	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;QRT	|	Number of enquiries to Credit Bureau about the client 3 month before application (excluding one month before application)	|
# |	122	|	AMT&#95;REQ&#95;CREDIT&#95;BUREAU&#95;YEAR	|	Number of enquiries to Credit Bureau about the client one day year (excluding last 3 months before application)	|
#
# </details>

# %% [markdown]
# Features that potentially have Time-based Leakage in the application_train.csv:
#
#
# | No. | Row | Description |
# |:-:|:--|:--|
# |	2	|	TARGET	|	Target variable (0 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 1 - all other cases)	|

# %% [markdown]
# By reviewing the business objectives, we can predict that the target variable will be imbalanced, and we will need to balance it using the "RepeatedStratifiedKFold" technique.

# %% [markdown]
# Target Variable Description:
# * Target variable = 0 → Rejected for a loan → Defaulter
# * Target variable = 1 → Accepted for a loan → Non-Defaulter

# %% [markdown]
# This objective belongs to the category of supervised learning, specifically **classification**.

# %% [markdown]
# ## Note
#
# To enhance clarity during the interpretation of model coefficients in later sections, I will change the target variable by assigning the value 0 to represent a defaulter and 1 to represent a non-defaulter. This adjustment aims to prevent any potential misinterpretations when evaluating creditworthiness.

# %% [markdown]
# <div id="four">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">4. Data preprocessing</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="libraries">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.1 Importing Required Libraries</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
from utils import *

# %% [markdown]
# <div id="reading">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.2 Importing and Reading the File</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
train = pd.read_csv("application_train.csv",chunksize=1000000)
train = pd.concat(train)

test_subm = pd.read_csv("application_test.csv",chunksize=1000000)
test_subm = pd.concat(test_subm)

# %%
train["TARGET"] = train["TARGET"].replace({0: 1, 1: 0})

# %% [markdown]
# <div id="rowscolumns">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.3 Determining the Number of Rows and Columns</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
print("Train:", train.shape)
print("Test_subm:", test_subm.shape)
# Out:
# Train: (307511, 122)
# Test_subm: (48744, 121)

# %% [markdown]
# <div id="pythondropcols">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.4 Dropping Unnecessary Columns and Removing > 70% Missing Values</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# Any missing values less than 70% will be handled using the WOE binning technique.

# %%
column_check(train)
# Out:
#                             Unique Values Data Types  \
# SK_ID_CURR                         307511      int64
# TARGET                                  2      int64
# NAME_CONTRACT_TYPE                      2     object
# CODE_GENDER                             3     object
# FLAG_OWN_CAR                            2     object
# ...                                   ...        ...
# AMT_REQ_CREDIT_BUREAU_DAY               9    float64
# AMT_REQ_CREDIT_BUREAU_WEEK              9    float64
# AMT_REQ_CREDIT_BUREAU_MON              24    float64
# AMT_REQ_CREDIT_BUREAU_QRT              11    float64
# AMT_REQ_CREDIT_BUREAU_YEAR             25    float64
#
#                                                                      Examples
# SK_ID_CURR                             384575, 214010, 142232, 389171, 283617
# TARGET                                                          1, 1, 1, 1, 1
# NAME_CONTRACT_TYPE          Cash loans, Cash loans, Cash loans, Cash loans...
# ...

# %%
missing_cols = train.columns[train.isnull().any()].tolist()
missing_percent = train[missing_cols].isnull().sum()* 100 / len(train)
columns_to_drop = missing_percent[missing_percent > 70] # Missing values' treshold = 70%
print(columns_to_drop)
# Out:
# Series([], dtype: float64)

# %%
missing_cols = test_subm.columns[test_subm.isnull().any()].tolist()
missing_percent = test_subm[missing_cols].isnull().sum()* 100 / len(test_subm)
columns_to_drop = missing_percent[missing_percent > 70] # Missing values' treshold = 70%
print(columns_to_drop)
# Out:
# Series([], dtype: float64)

# %%
train.isnull().sum().sum(), test_subm.isnull().sum().sum()
# Out:
# (9152465, 1404419)

# %%
missing_cols_num_train = train.loc[:, train.isnull().any()].select_dtypes(include = "number")
missing_cols_num_test = test_subm.loc[:, test_subm.isnull().any()].select_dtypes(include = "number")

# %%
missing_cols_num_train.isnull().sum().sum(), missing_cols_num_test.isnull().sum().sum()
# Out:
# (8388094, 1285385)

# %%
missing_cols_cat_train = train.loc[:, train.isnull().any()].select_dtypes(include = "object")
missing_cols_cat_test = test_subm.loc[:, test_subm.isnull().any()].select_dtypes(include = "object")

# %%
missing_cols_cat_train.isnull().sum().sum(), missing_cols_cat_test.isnull().sum().sum()
# Out:
# (764371, 119034)

# %% [markdown]
# <div id="dupvalues">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.5 Removing Duplicated Values</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
train.duplicated().sum(), test_subm.duplicated().sum()
# Out:
# (0, 0)

# %% [markdown]
# <div id="splittingtraintest">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.6 Splitting the Dataset into Training and Test Sets</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_bef_split = train.drop(columns="TARGET", axis=1)
y_bef_split = train["TARGET"]

# %%
print(f"(X_bef_split, y_bef_split): {X_bef_split.shape}, {y_bef_split.shape}")
# Out:
# (X_bef_split, y_bef_split): (307511, 121), (307511,)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_bef_split, y_bef_split, test_size = 0.20, random_state = random_state_)
X_train, X_test = X_train.copy(), X_test.copy()

# %%
print(f"training shapes: {X_train.shape}, {y_train.shape}")
print(f"testing shapes: {X_test.shape}, {y_test.shape}")
# Out:
# training shapes: (246008, 121), (246008,)
# testing shapes: (61503, 121), (61503,)

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
train.shape, test.shape, test_subm.shape
# Out:
# ((246008, 122), (61503, 122), (48744, 121))

# %% [markdown]
# <div id="convdatatypes">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.7 Converting Data Types</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
numeric_count_train = len(train.select_dtypes(include="number").columns)
object_count_train = len(train.select_dtypes(include="object").columns)
numeric_count_test = len(test.select_dtypes(include="number").columns)
object_count_test = len(test.select_dtypes(include="object").columns)
numeric_count_test_subm = len(test_subm.select_dtypes(include="number").columns)
object_count_test_subm = len(test_subm.select_dtypes(include="object").columns)

print("Train Numeric column count:", numeric_count_train)
print("Train Object column count:", object_count_train)
print("Test Numeric column count:", numeric_count_test)
print("Test Object column count:", object_count_test)
print("Test_subm Numeric column count:", numeric_count_test_subm)
print("Test_subm Object column count:", object_count_test_subm)
# Out:
# Train Numeric column count: 106
# Train Object column count: 16
# Test Numeric column count: 106
# Test Object column count: 16
# Test_subm Numeric column count: 105
# Test_subm Object column count: 16

# %%
column_check(train)
# Out:
#                             Unique Values Data Types  \
# SK_ID_CURR                         246008      int64
# NAME_CONTRACT_TYPE                      2     object
# CODE_GENDER                             3     object
# FLAG_OWN_CAR                            2     object
# FLAG_OWN_REALTY                         2     object
# ...                                   ...        ...
# AMT_REQ_CREDIT_BUREAU_WEEK              9    float64
# AMT_REQ_CREDIT_BUREAU_MON              23    float64
# AMT_REQ_CREDIT_BUREAU_QRT              11    float64
# AMT_REQ_CREDIT_BUREAU_YEAR             22    float64
# TARGET                                  2      int64
#
#                                                                      Examples
# SK_ID_CURR                             168688, 449725, 438870, 180087, 173238
# NAME_CONTRACT_TYPE          Cash loans, Cash loans, Cash loans, Cash loans...
# CODE_GENDER                                                     M, F, F, F, F
# ...

# %% [markdown]
# ### intruders

# %%
train_num = train.select_dtypes(include = "number")
test_num = test.select_dtypes(include = "number")
test_subm_num = test_subm.select_dtypes(include = "number")

# %%
train_object = train.select_dtypes(include = "object")
test_object = test.select_dtypes(include = "object")
test_subm_object = test_subm.select_dtypes(include = "object")

# %% [markdown]
# ### Uncomment the following codes if you want to check it yourself.

# %%
# column_check(train_num)

# %%
# column_check(test_num)

# %%
# column_check(test_subm_num)

# %%
# column_check(train_object)

# %%
# column_check(test_object)

# %%
# column_check(test_subm_object)

# %% [markdown]
# Based on the table above, the **numerical inputs** still maintain the correct data types (integer or float). This indicates that there are no intruders such as strings present.

# %%
# object_input_check(train, train_object)

# %%
# object_input_check(test, test_object)

# %%
# object_input_check(test_subm, test_subm_object)

# %% [markdown]
# Only NaN values found in the "object" column, which is missing values.

# %% [markdown]
# <div id="pythonaddcols">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.8 Creating New Features</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
train = train.assign(AGE_IN_YEARS = (train["DAYS_BIRTH"] / -365.25).round())
test = test.assign(AGE_IN_YEARS = (test["DAYS_BIRTH"] / -365.25).round())
test_subm = test_subm.assign(AGE_IN_YEARS = (test_subm["DAYS_BIRTH"] / -365.25).round())

# %%
train = train.assign(ANNUITY_INCOME_RATIO = train["AMT_ANNUITY"] / train["AMT_INCOME_TOTAL"])
test = test.assign(ANNUITY_INCOME_RATIO = test["AMT_ANNUITY"] / test["AMT_INCOME_TOTAL"])
test_subm = test_subm.assign(ANNUITY_INCOME_RATIO = test_subm["AMT_ANNUITY"] / test_subm["AMT_INCOME_TOTAL"])

# %%
train = train.assign(LOAN_DURATION = train["AMT_CREDIT"] / train["AMT_ANNUITY"])
test = test.assign(LOAN_DURATION = test["AMT_CREDIT"] / test["AMT_ANNUITY"])
test_subm = test_subm.assign(LOAN_DURATION = test_subm["AMT_CREDIT"] / test_subm["AMT_ANNUITY"])

# %%
train.head(1)
# Out:
#         SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 123473      243191         Cash loans           F            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 123473               N             0          171000.0    555273.0
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  ... AMT_REQ_CREDIT_BUREAU_HOUR  \
# 123473      16366.5         463500.0  ...                        0.0
#
#        AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# 123473                       0.0                        0.0
#
#        AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# 123473                       0.0                       1.0
#
#         AMT_REQ_CREDIT_BUREAU_YEAR  TARGET  AGE_IN_YEARS  \
# 123473                         1.0       1          64.0
#
#         ANNUITY_INCOME_RATIO  LOAN_DURATION
# 123473              0.095711      33.927413
#
# [1 rows x 125 columns]

# %%
test.head(1)
# Out:
#         SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 245895      384575         Cash loans           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 245895               N             2          207000.0    465457.5
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  ... AMT_REQ_CREDIT_BUREAU_HOUR  \
# 245895      52641.0         418500.0  ...                        0.0
#
#        AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# 245895                       0.0                        0.0
#
#        AMT_REQ_CREDIT_BUREAU_MON AMT_REQ_CREDIT_BUREAU_QRT  \
# 245895                       1.0                       0.0
#
#         AMT_REQ_CREDIT_BUREAU_YEAR  TARGET  AGE_IN_YEARS  \
# 245895                         1.0       1          36.0
#
#         ANNUITY_INCOME_RATIO  LOAN_DURATION
# 245895              0.254304        8.84211
#
# [1 rows x 125 columns]

# %%
test_subm.head(1)
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100001         Cash loans           F            N               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          135000.0    568800.0      20560.5         450000.0
#
#    ... FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 0  ...                0                        0.0                       0.0
#
#   AMT_REQ_CREDIT_BUREAU_WEEK AMT_REQ_CREDIT_BUREAU_MON  \
# 0                        0.0                       0.0
#
#    AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  AGE_IN_YEARS  \
# 0                        0.0                         0.0          53.0
#
#    ANNUITY_INCOME_RATIO  LOAN_DURATION
# 0                0.1523      27.664697
#
# [1 rows x 124 columns]

# %%
train.shape, test.shape, test_subm.shape
# Out:
# ((246008, 125), (61503, 125), (48744, 124))

# %% [markdown]
# <div id="outliers">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.9 Detecting and Handling Outliers</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
num_cols = train.select_dtypes(include="number").columns.tolist()
outlier_percentage = count_outliers(train, num_cols)
print(outlier_percentage)
# Out:
# {'SK_ID_CURR': '0.00%', 'CNT_CHILDREN': '1.36%', 'AMT_INCOME_TOTAL': '4.56%', 'AMT_CREDIT': '2.15%', 'AMT_ANNUITY': '2.40%', 'AMT_GOODS_PRICE': '4.81%', 'REGION_POPULATION_RELATIVE': '2.72%', 'DAYS_BIRTH': '0.00%', 'DAYS_EMPLOYED': '23.50%', 'DAYS_REGISTRATION': '0.20%', 'DAYS_ID_PUBLISH': '0.00%', 'OWN_CAR_AGE': '1.60%', 'FLAG_MOBIL': '0.00%', 'FLAG_EMP_PHONE': '18.02%', 'FLAG_WORK_PHONE': '19.89%', 'FLAG_CONT_MOBILE': '0.19%', 'FLAG_PHONE': '0.00%', 'FLAG_EMAIL': '5.70%', 'CNT_FAM_MEMBERS': '1.28%', 'REGION_RATING_CLIENT': '26.19%', 'REGION_RATING_CLIENT_W_CITY': '25.37%', 'HOUR_APPR_PROCESS_START': '0.74%', 'REG_REGION_NOT_LIVE_REGION': '1.52%', 'REG_REGION_NOT_WORK_REGION': '5.09%', 'LIVE_REGION_NOT_WORK_REGION': '4.07%', 'REG_CITY_NOT_LIVE_CITY': '7.84%', 'REG_CITY_NOT_WORK_CITY': '23.01%', 'LIVE_CITY_NOT_WORK_CITY': '17.91%', 'EXT_SOURCE_1': '0.00%', 'EXT_SOURCE_2': '0.00%', 'EXT_SOURCE_3': '0.00%', 'APARTMENTS_AVG': '3.45%', 'BASEMENTAREA_AVG': '2.35%', 'YEARS_BEGINEXPLUATATIO
# ...

# %% [markdown]
# <div id="dropsavecols">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.10 Dropping and Saving Columns</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# For the last calculation

IDs_test = test["SK_ID_CURR"]
CREDIT_test = test["AMT_CREDIT"]

IDs_test_subm = test_subm["SK_ID_CURR"]
CREDIT_test_subm = test_subm["AMT_CREDIT"]

# %%
train = train.drop("SK_ID_CURR", axis=1)
test = test.drop("SK_ID_CURR", axis=1)
test_subm = test_subm.drop("SK_ID_CURR", axis=1)

# %%
train.shape, test.shape, test_subm.shape
# Out:
# ((246008, 124), (61503, 124), (48744, 123))

# %% [markdown]
# <div id="five">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">5. Exploratory Data Analysis (EDA) and Data Visualization</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="edadist">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.1 Analyzing Numerical Distribution</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
selected_cols = ["AMT_CREDIT","AMT_ANNUITY","ANNUITY_INCOME_RATIO","AMT_GOODS_PRICE",
                 "LOAN_DURATION","AGE_IN_YEARS","EXT_SOURCE_1","EXT_SOURCE_2",
                 "EXT_SOURCE_3","DAYS_REGISTRATION","DAYS_ID_PUBLISH","REGION_POPULATION_RELATIVE"]
plot_histograms(train, selected_cols)

# %% [markdown]
# <div id="edaplothist">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.2 Plotting Histograms of Selected Categorical Variables to Target Variable</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
cat_dist(train, "NAME_CONTRACT_TYPE", "TARGET", "Defaulter", "Non-Defaulter", 0, 0.1)

# %%
cat_dist(train, "CODE_GENDER", "TARGET", "Defaulter", "Non-Defaulter", 1)

# %%
cat_dist(train, "FLAG_OWN_CAR", "TARGET", "Defaulter", "Non-Defaulter", 2, 0.10)

# %%
cat_dist(train, "HOUSETYPE_MODE", "TARGET", "Defaulter", "Non-Defaulter", 3)

# %%
cat_dist_top5(train, "OCCUPATION_TYPE", "TARGET", "Defaulter", "Non-Defaulter", 4, 0.02)

# %% [markdown]
# <div id="edatarvarpro">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.3 Checking Target Variable Proportions</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
target_dist(train, "TARGET", "Defaulter", "Non-Defaulter")

# %% [markdown]
# <div id="six">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">6. Feature Selection and Engineering</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
numeric_count_train = len(train.select_dtypes(include="number").columns)
object_count_train = len(train.select_dtypes(include="object").columns)
numeric_count_test = len(test.select_dtypes(include="number").columns)
object_count_test = len(test.select_dtypes(include="object").columns)
numeric_count_test_subm = len(test_subm.select_dtypes(include="number").columns)
object_count_test_subm = len(test_subm.select_dtypes(include="object").columns)

print("Train Numeric column count:", numeric_count_train)
print("Train Object column count:", object_count_train)
print("Test Numeric column count:", numeric_count_test)
print("Test Object column count:", object_count_test)
print("Test_subm Numeric column count:", numeric_count_test)
print("Test_subm Object column count:", object_count_test)
# Out:
# Train Numeric column count: 108
# Train Object column count: 16
# Test Numeric column count: 108
# Test Object column count: 16
# Test_subm Numeric column count: 108
# Test_subm Object column count: 16

# %%
X_train = train.drop(columns="TARGET", axis=1)
y_train = train["TARGET"]
X_test = test.drop(columns="TARGET", axis=1)
y_test = test["TARGET"]

# %%
print(f"training shapes: {X_train.shape}, {y_train.shape}")
print(f"testing shapes: {X_test.shape}, {y_test.shape}")
print(f"testing_subm shapes: {test_subm.shape}")
# Out:
# training shapes: (246008, 123), (246008,)
# testing shapes: (61503, 123), (61503,)
# testing_subm shapes: (48744, 123)

# %%
X_train_cat = X_train.select_dtypes(include = "object").copy()
X_train_num = X_train.select_dtypes(include = "number").copy()

# %% [markdown]
# <div id="utilchisquare">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.1 Chi Square Test (Categorical Features)</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
chi2_check = {}

for column in X_train_cat:
    chi, p, dof, ex = stats.chi2_contingency(pd.crosstab(y_train, X_train_cat[column]))
    chi2_check.setdefault("Feature",[]).append(column)
    chi2_check.setdefault("p-value",[]).append(round(p, 10))

chi2_result = pd.DataFrame(data = chi2_check)
chi2_result.sort_values(by = ["p-value"], ascending = True, ignore_index = True, inplace = True)
chi2_result
# Out:
#                        Feature       p-value
# 0           NAME_CONTRACT_TYPE  0.000000e+00
# 1                  CODE_GENDER  0.000000e+00
# 2                 FLAG_OWN_CAR  0.000000e+00
# 3             NAME_INCOME_TYPE  0.000000e+00
# 4          NAME_EDUCATION_TYPE  0.000000e+00
# 5           NAME_FAMILY_STATUS  0.000000e+00
# 6            NAME_HOUSING_TYPE  0.000000e+00
# 7              OCCUPATION_TYPE  0.000000e+00
# 8            ORGANIZATION_TYPE  0.000000e+00
# 9           WALLSMATERIAL_MODE  0.000000e+00
# 10         EMERGENCYSTATE_MODE  2.028000e-07
# 11              HOUSETYPE_MODE  1.548270e-05
# 12             FLAG_OWN_REALTY  5.671743e-04
# 13             NAME_TYPE_SUITE  2.784935e-03
# 14          FONDKAPREMONT_MODE  1.312237e-02
# 15  WEEKDAY_APPR_PROCESS_START  7.070656e-02

# %% [markdown]
# Let's keep only the top four categorical features

# %% [markdown]
# <div id="anovaa">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.2 ANOVA (Numerical Features)</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# since f_class_if does not accept missing values, we will do a very crude imputation of missing values
X_train_num.fillna(X_train_num.mean(), inplace = True)

F_statistic, p_values = feature_selection.f_classif(X_train_num, y_train)

ANOVA_F_table = pd.DataFrame(data = {"Numerical_Feature": X_train_num.columns.values, "F-Score": F_statistic, "p values": p_values.round(decimals=10)})
ANOVA_F_table.sort_values(by = ["F-Score"], ascending = False, ignore_index = True, inplace = True)
ANOVA_F_table
# Out:
#               Numerical_Feature      F-Score  p values
# 0                  EXT_SOURCE_2  6351.644583  0.000000
# 1                  EXT_SOURCE_3  6328.437711  0.000000
# 2                  EXT_SOURCE_1  2418.609627  0.000000
# 3                    DAYS_BIRTH  1491.612647  0.000000
# 4                  AGE_IN_YEARS  1491.457021  0.000000
# ..                          ...          ...       ...
# 102                  FLAG_MOBIL     0.087893  0.766873
# 103            FLAG_CONT_MOBILE     0.064415  0.799649
# 104            FLAG_DOCUMENT_19     0.028870  0.865079
# 105  AMT_REQ_CREDIT_BUREAU_WEEK     0.015467  0.901025
# 106                  FLAG_EMAIL     0.000029  0.995721
#
# [107 rows x 3 columns]

# %% [markdown]
# For the sake of simplicity, we will keep only the top 20 features and calculate pair-wise correlations between them

# %% [markdown]
# <div id="cormatrix">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.3 Correlation Matrix</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# save the top 20 numerical features in a list
top_num_features = ANOVA_F_table.iloc[:20,0].to_list()
corrmat = X_train_num[top_num_features].corr()
corrr(corrmat)

# %% [markdown]
# The following features can also be safely dropped given their multicollinearity with other features (> 0.7 or < -0.7):
# * REG_CITY_NOT_WORK_CITY
# * FLAG_EMP_PHONE
# * REGION_RATING_CLIENT_W_CITY
# * DAYS_BIRTH

# %%
drop_columns_list = ANOVA_F_table.iloc[20:, 0].to_list()
drop_columns_list.extend(chi2_result.iloc[4:, 0].to_list())
drop_columns_list.extend(["REG_CITY_NOT_WORK_CITY","FLAG_EMP_PHONE","REGION_RATING_CLIENT_W_CITY","DAYS_BIRTH"])

col_to_drop(X_train, drop_columns_list)
col_to_drop(X_test, drop_columns_list)
col_to_drop(test_subm, drop_columns_list)

# %% [markdown]
# <div id="dummyencod">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.4 Dummy Encoding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
dummy_cols = ["NAME_CONTRACT_TYPE","CODE_GENDER","FLAG_OWN_CAR","NAME_INCOME_TYPE"]

# %%
X_train = dummy_creation(X_train, dummy_cols)
X_test = dummy_creation(X_test, dummy_cols)
test_subm = dummy_creation(test_subm, dummy_cols)

# %%
X_train.shape
# Out:
# (246008, 35)

# %%
X_train.head(1)
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  AMT_GOODS_PRICE  \
# 123473         Cash loans           F            Y         463500.0
#
#        NAME_INCOME_TYPE  REGION_POPULATION_RELATIVE  DAYS_EMPLOYED  \
# 123473        Pensioner                    0.035792         365243
#
#         DAYS_REGISTRATION  DAYS_ID_PUBLISH  REGION_RATING_CLIENT  ...  \
# 123473            -3595.0            -4408                     2  ...
#
#         FLAG_OWN_CAR:N  FLAG_OWN_CAR:Y  NAME_INCOME_TYPE:Businessman  \
# 123473               0               1                             0
#
#         NAME_INCOME_TYPE:Commercial associate  \
# 123473                                      0
#
#         NAME_INCOME_TYPE:Maternity leave  NAME_INCOME_TYPE:Pensioner  \
# 123473                                 0                           1
#
#         NAME_INCOME_TYPE:State servant  NAME_INCOME_TYPE:Student  \
# 123473                               0                         0
#
# ...

# %%
X_test.head(1)
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  AMT_GOODS_PRICE  \
# 245895         Cash loans           M            Y         418500.0
#
#             NAME_INCOME_TYPE  REGION_POPULATION_RELATIVE  DAYS_EMPLOYED  \
# 245895  Commercial associate                     0.00963           -762
#
#         DAYS_REGISTRATION  DAYS_ID_PUBLISH  REGION_RATING_CLIENT  ...  \
# 245895             -637.0            -4307                     2  ...
#
#         FLAG_OWN_CAR:N  FLAG_OWN_CAR:Y  NAME_INCOME_TYPE:Businessman  \
# 245895               0               1                             0
#
#         NAME_INCOME_TYPE:Commercial associate  \
# 245895                                      1
#
#         NAME_INCOME_TYPE:Maternity leave  NAME_INCOME_TYPE:Pensioner  \
# 245895                                 0                           0
#
#         NAME_INCOME_TYPE:State servant  NAME_INCOME_TYPE:Student  \
# 245895                               0                         0
#
# ...

# %%
test_subm.head(1)
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  AMT_GOODS_PRICE  \
# 0         Cash loans           F            N         450000.0
#
#   NAME_INCOME_TYPE  REGION_POPULATION_RELATIVE  DAYS_EMPLOYED  \
# 0          Working                     0.01885          -2329
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  REGION_RATING_CLIENT  ...  \
# 0            -5170.0             -812                     2  ...
#
#    CODE_GENDER:M  FLAG_OWN_CAR:N  FLAG_OWN_CAR:Y  \
# 0              0               1               0
#
#    NAME_INCOME_TYPE:Businessman  NAME_INCOME_TYPE:Commercial associate  \
# 0                             0                                      0
#
#    NAME_INCOME_TYPE:Pensioner  NAME_INCOME_TYPE:State servant  \
# 0                           0                               0
#
#    NAME_INCOME_TYPE:Student  NAME_INCOME_TYPE:Unemployed  \
# 0                         0                            0
#
#    NAME_INCOME_TYPE:Working
# 0                         1
#
# ...

# %%
X_test = X_test.reindex(labels=X_train.columns, axis=1, fill_value=0)
test_subm = test_subm.reindex(labels=X_train.columns, axis=1, fill_value=0)

# %% [markdown]
# <div id="woeandiv">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.5 Weight of Evidence (WOE) and Information Value (IV)</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_train_prepr = X_train.copy()
y_train_prepr = y_train.copy()
X_test_prepr = X_test.copy()
y_test_prepr = y_test.copy()

# %% [markdown]
# <div id="discfeature">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.5.1 Discrete Features</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# ### 1. NAME_CONTRACT_TYPE

# %%
df_temp = woe_discrete(X_train_prepr, "NAME_CONTRACT_TYPE", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#   NAME_CONTRACT_TYPE   n_obs  five_percent  prop_good  prop_n_obs    n_good  \
# 0         Cash loans  222490       12300.4   0.916396    0.904401  203889.0
# 1    Revolving loans   23518       12300.4   0.945786    0.095599   22243.0
#
#      n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  diff_WoE  \
# 0  18601.0     0.901637    0.935852 -0.037246             NaN       NaN
# 1   1275.0     0.098363    0.064148  0.427475         0.02939  0.464721
#
#          IV
# 0  0.015901
# 1  0.015901

# %% [markdown]
# IV (< 0.02): close to the minimum ideal threshold, so we will proceed nevertheless

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 2. CODE_GENDER

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["CODE_GENDER"] != "XNA"]

df_temp = woe_discrete(X_train_check, "CODE_GENDER", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#   CODE_GENDER   n_obs  five_percent  prop_good  prop_n_obs    n_good    n_bad  \
# 0           M   84150      12300.25   0.898491    0.342066   75608.0   8542.0
# 1           F  161855      12300.25   0.929974    0.657934  150521.0  11334.0
#
#    prop_n_good  prop_n_bad       WoE  diff_prop_good  diff_WoE        IV
# 0     0.334358    0.429765 -0.251026             NaN       NaN  0.038709
# 1     0.665642    0.570235  0.154703        0.031484  0.405729  0.038709

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 3. FLAG_OWN_CAR

# %%
df_temp = woe_discrete(X_train_prepr, "FLAG_OWN_CAR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#   FLAG_OWN_CAR   n_obs  five_percent  prop_good  prop_n_obs    n_good  \
# 0            N  162183       12300.4   0.914664    0.659259  148343.0
# 1            Y   83825       12300.4   0.927993    0.340741   77789.0
#
#      n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  diff_WoE  \
# 0  13840.0     0.656002    0.696317 -0.059642             NaN       NaN
# 1   6036.0     0.343998    0.303683  0.124653        0.013329  0.184294
#
#         IV
# 0  0.00743
# 1  0.00743

# %% [markdown]
# IV (< 0.02): very far below the minimum ideal threshold, so we will not proceed further with it.

# %% [markdown]
# ### 4. NAME_INCOME_TYPE

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[(X_train_check["NAME_INCOME_TYPE"] != "Maternity leave") & (X_train_check["NAME_INCOME_TYPE"] != "Businessman")]

df_temp = woe_discrete(X_train_check, "NAME_INCOME_TYPE", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#        NAME_INCOME_TYPE   n_obs  five_percent  prop_good  prop_n_obs  \
# 0            Unemployed      19      12299.85   0.684211    0.000077
# 1               Working  126929      12299.85   0.904529    0.515978
# 2  Commercial associate   57339      12299.85   0.924327    0.233088
# 3         State servant   17381      12299.85   0.941660    0.070655
# 4             Pensioner   44314      12299.85   0.945886    0.180140
# 5               Student      15      12299.85   1.000000    0.000061
#
#      n_good    n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  \
# 0      13.0      6.0     0.000057    0.000302 -1.658422             NaN
# 1  114811.0  12118.0     0.507739    0.609711 -0.183017        0.220319
# 2   53000.0   4339.0     0.234387    0.218314  0.071036        0.019798
# 3   16367.0   1014.0     0.072381    0.051019  0.349752        0.017333
# 4   41916.0   2398.0     0.185369    0.120654  0.429421        0.004226
# ...

# %% [markdown]
# IV (> 0.5): Suspicious Predictive Power, so we won't proceed further with it

# %% [markdown]
# <div id="numcfeature">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.5.2 Numeric Features</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# ### 1. EXT_SOURCE_2

# %%
interval_check = X_train_prepr.copy()
interval_check["EXT_SOURCE_2"].min()
# Out:
# 8.173616518884397e-08

# %%
X_train_check = X_train_prepr.copy()
X_train_check["EXT_SOURCE_2_FACTOR"] = pd.cut(X_train_check["EXT_SOURCE_2"], 15)

df_temp = woe_ordered_continuous(X_train_check, "EXT_SOURCE_2_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    EXT_SOURCE_2_FACTOR  n_obs  five_percent  prop_good  prop_n_obs   n_good  \
# 0   (-0.000855, 0.057]   4911      12273.95   0.739971    0.020006   3634.0
# 1       (0.057, 0.114]   5446      12273.95   0.801873    0.022185   4367.0
# 2       (0.114, 0.171]   7549      12273.95   0.840906    0.030752   6348.0
# 3       (0.171, 0.228]   8351      12273.95   0.863489    0.034019   7211.0
# 4       (0.228, 0.285]  11650      12273.95   0.876996    0.047458  10217.0
# 5       (0.285, 0.342]  11758      12273.95   0.884844    0.047898  10404.0
# 6       (0.342, 0.399]  13288      12273.95   0.892911    0.054131  11865.0
# 7       (0.399, 0.456]  15528      12273.95   0.908745    0.063256  14111.0
# 8       (0.456, 0.513]  20127      12273.95   0.918021    0.081991  18477.0
# 9        (0.513, 0.57]  26281      12273.95   0.927476    0.107060  24375.0
# 10       (0.57, 0.627]  34348      12273.95   0.935135    0.139922  32120.0
# ...

# %% [markdown]
# IV (0.3 &ndash; 0.5): Strong Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 2. EXT_SOURCE_3

# %%
interval_check = X_train_prepr.copy()
interval_check["EXT_SOURCE_3"].min()
# Out:
# 0.0005272652387098

# %%
X_train_check = X_train_prepr.copy()
X_train_check["EXT_SOURCE_3_FACTOR"] = pd.cut(X_train_check["EXT_SOURCE_3"], 15)

df_temp = woe_ordered_continuous(X_train_check, "EXT_SOURCE_3_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#     EXT_SOURCE_3_FACTOR  n_obs  five_percent  prop_good  prop_n_obs   n_good  \
# 0   (-0.000368, 0.0602]   1748        9859.2   0.707094    0.008865   1236.0
# 1        (0.0602, 0.12]   4332        9859.2   0.756233    0.021969   3276.0
# 2          (0.12, 0.18]   6672        9859.2   0.812950    0.033836   5424.0
# 3         (0.18, 0.239]   8909        9859.2   0.838029    0.045181   7466.0
# 4        (0.239, 0.299]  11189        9859.2   0.870319    0.056744   9738.0
# 5        (0.299, 0.359]  13236        9859.2   0.890752    0.067125  11790.0
# 6        (0.359, 0.418]  15844        9859.2   0.908293    0.080351  14391.0
# 7        (0.418, 0.478]  17987        9859.2   0.920998    0.091219  16566.0
# 8        (0.478, 0.538]  19180        9859.2   0.938373    0.097270  17998.0
# 9        (0.538, 0.598]  22066        9859.2   0.947838    0.111906  20915.0
# 10       (0.598, 0.657]  22603        9859.2   0.954519    0.114629  21575.0
# ...

# %% [markdown]
# IV (0.3 &ndash; 0.5): Strong Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 3. EXT_SOURCE_1

# %%
interval_check = X_train_prepr.copy()
interval_check["EXT_SOURCE_1"].min()
# Out:
# 0.0145681324124455

# %%
X_train_check = X_train_prepr.copy()
X_train_check["EXT_SOURCE_1_FACTOR"] = pd.cut(X_train_check["EXT_SOURCE_1"], 15)

df_temp = woe_ordered_continuous(X_train_check, "EXT_SOURCE_1_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    EXT_SOURCE_1_FACTOR  n_obs  five_percent  prop_good  prop_n_obs  n_good  \
# 0      (0.0136, 0.077]    830        5374.2   0.698795    0.007722   580.0
# 1        (0.077, 0.14]   3007        5374.2   0.809445    0.027976  2434.0
# 2        (0.14, 0.202]   5623        5374.2   0.843678    0.052315  4744.0
# 3       (0.202, 0.264]   7644        5374.2   0.873888    0.071118  6680.0
# 4       (0.264, 0.327]   8665        5374.2   0.899942    0.080617  7798.0
# 5       (0.327, 0.389]   9559        5374.2   0.909928    0.088934  8698.0
# 6       (0.389, 0.452]   9849        5374.2   0.920804    0.091632  9069.0
# 7       (0.452, 0.514]   9810        5374.2   0.934455    0.091269  9167.0
# 8       (0.514, 0.577]  10039        5374.2   0.938839    0.093400  9425.0
# 9       (0.577, 0.639]  10016        5374.2   0.946785    0.093186  9483.0
# 10      (0.639, 0.702]   9672        5374.2   0.954921    0.089985  9236.0
# ...

# %% [markdown]
# IV (0.1 &ndash; 0.3): Medium Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 4. AGE_IN_YEARS

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["AGE_IN_YEARS"].max()
# Out:
# 69.0

# %%
X_train_check = X_train_prepr.copy()

df_temp = woe_ordered_continuous(X_train_check, "AGE_IN_YEARS", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp["AGE_IN_YEARS"] = df_temp["AGE_IN_YEARS"].astype(int)
df_temp
# Out:
#     AGE_IN_YEARS  n_obs  five_percent  prop_good  prop_n_obs  n_good  n_bad  \
# 0             21    545       12300.4   0.889908    0.002215   485.0   60.0
# 1             22   1608       12300.4   0.870025    0.006536  1399.0  209.0
# 2             23   2918       12300.4   0.860178    0.011861  2510.0  408.0
# 3             24   3092       12300.4   0.885188    0.012569  2737.0  355.0
# 4             25   3265       12300.4   0.887596    0.013272  2898.0  367.0
# 5             26   3493       12300.4   0.904094    0.014199  3158.0  335.0
# 6             27   5108       12300.4   0.881363    0.020764  4502.0  606.0
# 7             28   6776       12300.4   0.886364    0.027544  6006.0  770.0
# 8             29   6104       12300.4   0.890891    0.024812  5438.0  666.0
# 9             30   6195       12300.4   0.885876    0.025182  5488.0  707.0
# 10            31   6487       12300.4   0.895637    0.026369  5810.0  677.0
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 5. REGION_RATING_CLIENT

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["REGION_RATING_CLIENT"].value_counts()
# Out:
# 2    181590
# 3     38681
# 1     25737
# Name: REGION_RATING_CLIENT, dtype: int64

# %%
X_train_check = X_train_prepr.copy()
df_temp = woe_ordered_continuous(X_train_check, "REGION_RATING_CLIENT", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    REGION_RATING_CLIENT   n_obs  five_percent  prop_good  prop_n_obs  \
# 0                     1   25737       12300.4   0.951004    0.104619
# 1                     2  181590       12300.4   0.921102    0.738147
# 2                     3   38681       12300.4   0.889145    0.157235
#
#      n_good    n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  \
# 0   24476.0   1261.0     0.108238    0.063443  0.534182             NaN
# 1  167263.0  14327.0     0.739670    0.720819  0.025816        0.029902
# 2   34393.0   4288.0     0.152093    0.215738 -0.349573        0.031958
#
#    diff_WoE        IV
# 0       NaN  0.046664
# 1  0.508366  0.046664
# 2  0.375389  0.046664

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 6. DAYS_LAST_PHONE_CHANGE

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["DAYS_LAST_PHONE_CHANGE"].min()
# Out:
# -4292.0

# %%
X_train_check = X_train_prepr.copy()

X_train_check["DAYS_LAST_PHONE_CHANGE_FACTOR"] = pd.cut(X_train_check["DAYS_LAST_PHONE_CHANGE"], 15)

df_temp = woe_ordered_continuous(X_train_check, "DAYS_LAST_PHONE_CHANGE_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    DAYS_LAST_PHONE_CHANGE_FACTOR  n_obs  five_percent  prop_good  prop_n_obs  \
# 0         (-4296.292, -4005.867]     23      12300.35   0.913043    0.000093
# 1         (-4005.867, -3719.733]    100      12300.35   0.960000    0.000406
# 2           (-3719.733, -3433.6]    443      12300.35   0.961625    0.001801
# 3           (-3433.6, -3147.467]   1926      12300.35   0.955348    0.007829
# 4         (-3147.467, -2861.333]   2868      12300.35   0.949093    0.011658
# 5           (-2861.333, -2575.2]   5371      12300.35   0.944703    0.021833
# 6           (-2575.2, -2289.067]   9264      12300.35   0.943653    0.037657
# 7         (-2289.067, -2002.933]  10786      12300.35   0.939459    0.043844
# 8           (-2002.933, -1716.8]  18821      12300.35   0.938579    0.076506
# 9           (-1716.8, -1430.667]  23968      12300.35   0.934788    0.097428
# 10        (-1430.667, -1144.533]  18180      12300.35   0.930253    0.073900
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 7. DAYS_ID_PUBLISH

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["DAYS_ID_PUBLISH"].min()
# Out:
# -7197

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["DAYS_ID_PUBLISH"] >= -6439.421]

X_train_check["DAYS_ID_PUBLISH_FACTOR"] = pd.cut(X_train_check["DAYS_ID_PUBLISH"], 30)

df_temp = woe_ordered_continuous(X_train_check, "DAYS_ID_PUBLISH_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#     DAYS_ID_PUBLISH_FACTOR  n_obs  five_percent  prop_good  prop_n_obs  \
# 0   (-6389.383, -6170.233]     41       12300.3   0.926829    0.000167
# 1   (-6170.233, -5957.467]    406       12300.3   0.950739    0.001650
# 2     (-5957.467, -5744.7]    468       12300.3   0.948718    0.001902
# 3     (-5744.7, -5531.933]    992       12300.3   0.941532    0.004032
# 4   (-5531.933, -5319.167]   1480       12300.3   0.937162    0.006016
# 5     (-5319.167, -5106.4]   3405       12300.3   0.931571    0.013841
# 6     (-5106.4, -4893.633]   7792       12300.3   0.939425    0.031674
# 7   (-4893.633, -4680.867]  13015       12300.3   0.942067    0.052905
# 8     (-4680.867, -4468.1]  17936       12300.3   0.939674    0.072909
# 9     (-4468.1, -4255.333]  20088       12300.3   0.936330    0.081657
# 10  (-4255.333, -4042.567]  21001       12300.3   0.928146    0.085368
# 11    (-4042.567, -3829.8]  13614       12300.3   0.919935    0.055340
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 8. DAYS_EMPLOYED

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["DAYS_EMPLOYED"].min()
# Out:
# -17912

# %%
X_train_check = X_train_prepr.copy()
X_train_check["DAYS_EMPLOYED_FACTOR"] = pd.cut(X_train_check["DAYS_EMPLOYED"], 30)

df_temp = woe_ordered_continuous(X_train_check, "DAYS_EMPLOYED_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#         DAYS_EMPLOYED_FACTOR   n_obs  five_percent  prop_good  prop_n_obs  \
# 0    (-18295.155, -5140.167]   22100       12300.4   0.953213    0.089834
# 1      (-5140.167, 7631.667]  179584       12300.4   0.908466    0.729993
# 2        (7631.667, 20403.5]       0       12300.4        NaN    0.000000
# 3       (20403.5, 33175.333]       0       12300.4        NaN    0.000000
# 4     (33175.333, 45947.167]       0       12300.4        NaN    0.000000
# 5       (45947.167, 58719.0]       0       12300.4        NaN    0.000000
# 6       (58719.0, 71490.833]       0       12300.4        NaN    0.000000
# 7     (71490.833, 84262.667]       0       12300.4        NaN    0.000000
# 8       (84262.667, 97034.5]       0       12300.4        NaN    0.000000
# 9      (97034.5, 109806.333]       0       12300.4        NaN    0.000000
# 10  (109806.333, 122578.167]       0       12300.4        NaN    0.000000
# 11    (122578.167, 135350.0]       0       12300.4        NaN    0.000000
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 9. FLAG_DOCUMENT_3

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["FLAG_DOCUMENT_3"].value_counts()
# Out:
# 1    174637
# 0     71371
# Name: FLAG_DOCUMENT_3, dtype: int64

# %%
X_train_check = X_train_prepr.copy()
df_temp = woe_ordered_continuous(X_train_check, "FLAG_DOCUMENT_3", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    FLAG_DOCUMENT_3   n_obs  five_percent  prop_good  prop_n_obs    n_good  \
# 0                0   71371       12300.4   0.938196    0.290117   66960.0
# 1                1  174637       12300.4   0.911445    0.709883  159172.0
#
#      n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  diff_WoE  \
# 0   4411.0      0.29611    0.221926  0.288388             NaN       NaN
# 1  15465.0      0.70389    0.778074 -0.100200        0.026751  0.388588
#
#          IV
# 0  0.028827
# 1  0.028827

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 10. REG_CITY_NOT_LIVE_CITY

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["REG_CITY_NOT_LIVE_CITY"].value_counts()
# Out:
# 0    226730
# 1     19278
# Name: REG_CITY_NOT_LIVE_CITY, dtype: int64

# %%
X_train_check = X_train_prepr.copy()
df_temp = woe_ordered_continuous(X_train_check, "REG_CITY_NOT_LIVE_CITY", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    REG_CITY_NOT_LIVE_CITY   n_obs  five_percent  prop_good  prop_n_obs  \
# 0                       0  226730       12300.4   0.922741    0.921637
# 1                       1   19278       12300.4   0.877633    0.078363
#
#      n_good    n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  \
# 0  209213.0  17517.0     0.925181    0.881314  0.048575             NaN
# 1   16919.0   2359.0     0.074819    0.118686 -0.461406        0.045108
#
#    diff_WoE        IV
# 0       NaN  0.022371
# 1  0.509982  0.022371

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp)

# %% [markdown]
# ### 11. DAYS_REGISTRATION

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["DAYS_REGISTRATION"].min()
# Out:
# -23416.0

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["DAYS_REGISTRATION"] >= -16391.2]

X_train_check["DAYS_REGISTRATION_FACTOR"] = pd.cut(X_train_check["DAYS_REGISTRATION"], 30)

df_temp = woe_ordered_continuous(X_train_check, "DAYS_REGISTRATION_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#     DAYS_REGISTRATION_FACTOR  n_obs  five_percent  prop_good  prop_n_obs  \
# 0   (-16407.391, -15844.633]    169       12287.1   0.970414    0.000688
# 1   (-15844.633, -15298.267]    281       12287.1   0.957295    0.001143
# 2     (-15298.267, -14751.9]    458       12287.1   0.958515    0.001864
# 3     (-14751.9, -14205.533]    662       12287.1   0.960725    0.002694
# 4   (-14205.533, -13659.167]   1027       12287.1   0.944499    0.004179
# 5     (-13659.167, -13112.8]   1558       12287.1   0.954429    0.006340
# 6     (-13112.8, -12566.433]   2129       12287.1   0.945045    0.008664
# 7   (-12566.433, -12020.067]   2517       12287.1   0.938816    0.010242
# 8     (-12020.067, -11473.7]   2890       12287.1   0.939446    0.011760
# 9     (-11473.7, -10927.333]   3405       12287.1   0.943906    0.013856
# 10  (-10927.333, -10380.967]   4435       12287.1   0.941601    0.018047
# 11     (-10380.967, -9834.6]   6005       12287.1   0.943214    0.024436
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 12. AMT_GOODS_PRICE

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["AMT_GOODS_PRICE"].min()
# Out:
# 40500.0

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["AMT_GOODS_PRICE"] <= 2267775.0]

X_train_check["AMT_GOODS_PRICE_FACTOR"] = pd.cut(X_train_check["AMT_GOODS_PRICE"], 20)

df_temp = woe_ordered_continuous(X_train_check, "AMT_GOODS_PRICE_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#     AMT_GOODS_PRICE_FACTOR  n_obs  five_percent  prop_good  prop_n_obs  \
# 0      (38286.0, 151200.0]  19732      12286.25   0.934066    0.080301
# 1     (151200.0, 261900.0]  50497      12286.25   0.913896    0.205502
# 2     (261900.0, 372600.0]  27531      12286.25   0.908612    0.112040
# 3     (372600.0, 483300.0]  44532      12286.25   0.892661    0.181227
# 4     (483300.0, 594000.0]  13770      12286.25   0.926434    0.056038
# 5     (594000.0, 704700.0]  32981      12286.25   0.919590    0.134219
# 6     (704700.0, 815400.0]   7357      12286.25   0.938970    0.029940
# 7     (815400.0, 926100.0]  18686      12286.25   0.934015    0.076044
# 8    (926100.0, 1036800.0]   4366      12286.25   0.942510    0.017768
# 9   (1036800.0, 1147500.0]  11200      12286.25   0.943571    0.045579
# 10  (1147500.0, 1258200.0]   1882      12286.25   0.941552    0.007659
# 11  (1258200.0, 1368900.0]   6621      12286.25   0.952726    0.026945
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 13. REGION_POPULATION_RELATIVE

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["REGION_POPULATION_RELATIVE"].min()
# Out:
# 0.00029

# %%
X_train_check = X_train_prepr.copy()
X_train_check["REGION_POPULATION_RELATIVE_FACTOR"] = pd.cut(X_train_check["REGION_POPULATION_RELATIVE"], 20)

df_temp = woe_ordered_continuous(X_train_check, "REGION_POPULATION_RELATIVE_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    REGION_POPULATION_RELATIVE_FACTOR  n_obs  five_percent  prop_good  \
# 0                 (0.000218, 0.0039]   9052       12300.4   0.903999
# 1                  (0.0039, 0.00751]  31312       12300.4   0.912781
# 2                  (0.00751, 0.0111]  38413       12300.4   0.918309
# 3                   (0.0111, 0.0147]  11664       12300.4   0.920868
# 4                   (0.0147, 0.0183]  18732       12300.4   0.900918
# 5                    (0.0183, 0.022]  40746       12300.4   0.909635
# 6                    (0.022, 0.0256]  23258       12300.4   0.920157
# 7                   (0.0256, 0.0292]  18127       12300.4   0.926574
# 8                   (0.0292, 0.0328]  24105       12300.4   0.926198
# 9                   (0.0328, 0.0364]  13125       12300.4   0.930667
# 10                    (0.0364, 0.04]      0       12300.4        NaN
# 11                    (0.04, 0.0436]      0       12300.4        NaN
# 12                  (0.0436, 0.0472]  10793       12300.4   0.951172
# ...

# %% [markdown]
# IV (0.02 &ndash; 0.1): Weak Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 14. LOAN_DURATION

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["LOAN_DURATION"].min()
# Out:
# 8.036674497520229

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["LOAN_DURATION"] <= 40.336]

X_train_check["LOAN_DURATION_FACTOR"] = pd.cut(X_train_check["LOAN_DURATION"], 30)

df_temp = woe_ordered_continuous(X_train_check, "LOAN_DURATION_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#    LOAN_DURATION_FACTOR  n_obs  five_percent  prop_good  prop_n_obs   n_good  \
# 0        (8.005, 9.092]   3929      12298.45   0.905319    0.015974   3557.0
# 1       (9.092, 10.148]  15997      12298.45   0.955554    0.065037  15286.0
# 2      (10.148, 11.203]   7740      12298.45   0.947287    0.031467   7332.0
# 3      (11.203, 12.259]    936      12298.45   0.898504    0.003805    841.0
# 4      (12.259, 13.314]  12194      12298.45   0.853206    0.049575  10404.0
# 5       (13.314, 14.37]   8157      12298.45   0.925831    0.033163   7552.0
# 6       (14.37, 15.425]  10402      12298.45   0.864738    0.042290   8995.0
# 7      (15.425, 16.481]   7176      12298.45   0.908724    0.029174   6521.0
# 8      (16.481, 17.536]   5685      12298.45   0.927353    0.023113   5272.0
# 9      (17.536, 18.592]  12136      12298.45   0.895023    0.049340  10862.0
# 10     (18.592, 19.647]  17486      12298.45   0.910443    0.071090  15920.0
# ...

# %% [markdown]
# IV (0.1 &ndash; 0.3): Medium Predictive Power

# %%
plot_by_woe(df_temp, 90)

# %% [markdown]
# ### 15. LIVE_CITY_NOT_WORK_CITY

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["LIVE_CITY_NOT_WORK_CITY"].min()
# Out:
# 0

# %%
X_train_check = X_train_prepr.copy()
X_train_check["LIVE_CITY_NOT_WORK_CITY_FACTOR"] = pd.cut(X_train_check["LIVE_CITY_NOT_WORK_CITY"], 10)

df_temp = woe_ordered_continuous(X_train_check, "LIVE_CITY_NOT_WORK_CITY_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#   LIVE_CITY_NOT_WORK_CITY_FACTOR   n_obs  five_percent  prop_good  prop_n_obs  \
# 0                  (-0.001, 0.1]  201936       12300.4   0.923431    0.820851
# 1                     (0.1, 0.2]       0       12300.4        NaN    0.000000
# 2                     (0.2, 0.3]       0       12300.4        NaN    0.000000
# 3                     (0.3, 0.4]       0       12300.4        NaN    0.000000
# 4                     (0.4, 0.5]       0       12300.4        NaN    0.000000
# 5                     (0.5, 0.6]       0       12300.4        NaN    0.000000
# 6                     (0.6, 0.7]       0       12300.4        NaN    0.000000
# 7                     (0.7, 0.8]       0       12300.4        NaN    0.000000
# 8                     (0.8, 0.9]       0       12300.4        NaN    0.000000
# 9                     (0.9, 1.0]   44072       12300.4   0.899846    0.179149
#
#      n_good    n_bad  prop_n_good  prop_n_bad       WoE  diff_prop_good  \
# ...

# %% [markdown]
# IV (< 0.02): very far below the minimum ideal threshold, so we will not proceed further with it.

# %% [markdown]
# ### 16. DEF_30_CNT_SOCIAL_CIRCLE

# %%
interval_check = X_train_prepr.copy()

# %%
interval_check["DEF_30_CNT_SOCIAL_CIRCLE"].min()
# Out:
# 0.0

# %%
X_train_check = X_train_prepr.copy()

# filter out all values giving the low obs
X_train_check = X_train_check[X_train_check["DEF_30_CNT_SOCIAL_CIRCLE"] <= 6.0]
X_train_check["DEF_30_CNT_SOCIAL_CIRCLE_FACTOR"] = pd.cut(X_train_check["DEF_30_CNT_SOCIAL_CIRCLE"], 5)

df_temp = woe_ordered_continuous(X_train_check, "DEF_30_CNT_SOCIAL_CIRCLE_FACTOR", y_train_prepr)
new_column = df_temp["n_obs"].sum()*0.05
df_temp.insert(2, "five_percent", new_column)
df_temp
# Out:
#   DEF_30_CNT_SOCIAL_CIRCLE_FACTOR   n_obs  five_percent  prop_good  \
# 0                   (-0.006, 1.2]  239734      12260.05   0.920007
# 1                      (1.2, 2.4]    4247      12260.05   0.879680
# 2                      (2.4, 3.6]     966      12260.05   0.868530
# 3                      (3.6, 4.8]     199      12260.05   0.869347
# 4                      (4.8, 6.0]      55      12260.05   0.890909
#
#    prop_n_obs    n_good    n_bad  prop_n_good  prop_n_bad       WoE  \
# 0    0.977704  220557.0  19177.0     0.978713    0.966242  0.012825
# 1    0.017320    3736.0    511.0     0.016578    0.025747 -0.440218
# 2    0.003940     839.0    127.0     0.003723    0.006399 -0.541596
# 3    0.000812     173.0     26.0     0.000768    0.001310 -0.534425
# 4    0.000224      49.0      6.0     0.000217    0.000302 -0.329559
#
#    diff_prop_good  diff_WoE        IV
# 0             NaN       NaN  0.005963
# 1        0.040327  0.453043  0.005963
# ...

# %% [markdown]
# IV (< 0.02): very far below the minimum ideal threshold, so we will not proceed further with it.

# %% [markdown]
# <div id="seven">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">7. Model Selection and Building</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
print(X_bef_split.shape)
print(y_bef_split.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(test_subm.shape)
# Out:
# (307511, 121)
# (307511,)
# (246008, 35)
# (246008,)
# (61503, 35)
# (61503,)
# (48744, 35)

# %% [markdown]
# <div id="trainml">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.1 Training the Machine Learning Model</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
reg = linear_model.LogisticRegression(max_iter=1000, class_weight = "balanced")
woe_transform = WoE_Binning(X_bef_split)
pipeline = pipeline.Pipeline(steps=[("woe", woe_transform), ("model", reg)])

# RepeatedStratifiedKFold automatially takes care of the class imbalance while splitting
cv = model_selection.RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=random_state_)

scores = model_selection.cross_val_score(pipeline, X_train, y_train, scoring = "roc_auc", cv = cv)
AUROC = np.mean(scores)
GINI = AUROC * 2 - 1

print("Mean AUROC: %.4f" % (AUROC))
print("Gini: %.4f" % (GINI))
# Out:
# Mean AUROC: 0.7393
# Gini: 0.4785

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('woe',
#                  WoE_Binning(X=        SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002         Cash loans           M            N
# 1           100003         Cash loans           F            N
# 2           100004    Revolving loans           M            Y
# 3           100006         Cash loans           F            N
# 4           100007         Cash loans           M            N
# ...            ...                ...         ...          ...
# 307506      456251         Cash loans           M            N
# 307507      456252         Cash loans           F            N
# 307508      456253         Cash loans           F            N
# 307509      456254         Cash loans           F            N
# 307510      456255         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOM...
# 307510                        0.0                         0.0
#
# ...

# %%
X_train_woe_transformed = woe_transform.fit_transform(X_train)
feature_name = X_train_woe_transformed.columns.values
summary_table = pd.DataFrame(columns = ["Feature name"], data = feature_name)

summary_table["Coefficients"] = np.transpose(pipeline["model"].coef_)

# Increase the index of every row of the dataframe with 1 to store our model "intercept" in 1st row
summary_table.index = summary_table.index + 1

summary_table.loc[0] = ["Intercept", pipeline["model"].intercept_[0]]

summary_table.sort_index(inplace = True)
summary_table
# Out:
#                           Feature name  Coefficients
# 0                            Intercept     -0.320272
# 1   NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2                        CODE_GENDER:M     -0.273369
# 3                 EXT_SOURCE_2:missing     -0.185798
# 4                 EXT_SOURCE_2:<=0.171     -0.857951
# ..                                 ...           ...
# 75          LOAN_DURATION:10.148–14.37      0.687648
# 76          LOAN_DURATION:14.37–21.758      0.618108
# 77         LOAN_DURATION:21.758–28.092      0.998825
# 78         LOAN_DURATION:28.092–31.258      0.748501
# 79         LOAN_DURATION:31.258–39.702      0.925086
#
# [80 rows x 2 columns]

# %% [markdown]
# <div id="testml">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.2 Testing the Machine Learning Model</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
y_hat_test = pipeline.predict(X_test)
y_hat_test_proba = pipeline.predict_proba(X_test)
y_hat_test_proba
# Out:
# array([[0.56595403, 0.43404597],
#        [0.33756289, 0.66243711],
#        [0.55132946, 0.44867054],
#        ...,
#        [0.15601234, 0.84398766],
#        [0.46200215, 0.53799785],
#        [0.38935189, 0.61064811]])

# %%
# select the probabilities of only the positive class (class 1 - default) 
y_hat_test_proba = y_hat_test_proba[:][: , 1]

# %%
y_test_temp = y_test.copy()
y_test_temp.reset_index(drop = True, inplace = True)
y_test_proba = pd.concat([y_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

y_test_proba.shape, y_test.shape
# Out:
# ((61503, 2), (61503,))

# %%
y_test_proba.columns = ["y_test_class_actual", "y_hat_test_proba"]

y_test_proba.index = X_test.index
y_test_proba.head()
# Out:
#         y_test_class_actual  y_hat_test_proba
# 245895                    1          0.434046
# 98194                     1          0.662437
# 36463                     1          0.448671
# 249923                    1          0.849081
# 158389                    1          0.651030

# %% [markdown]
# <div id="confmatrixauroctest">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.3 Confusion Matrix and AUROC on Test Set</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# threshold
tr = 0.5

y_test_proba['y_test_class_predicted'] = np.where(y_test_proba['y_hat_test_proba'] > tr, 1, 0)
cm = metrics.confusion_matrix(y_test_proba['y_test_class_actual'], y_test_proba['y_test_class_predicted'], normalize='all')
True_Pos, True_Neg, False_Pos, False_Neg = confusion_matrix_mod(cm)

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test_proba['y_test_class_actual'], y_test_proba['y_hat_test_proba'])

plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %%
# calculate the no skill line as the proportion of the positive class
no_skill = len(y_test[y_test == 1]) / len(y_bef_split)

plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')

precision, recall, thresholds = metrics.precision_recall_curve(y_test_proba['y_test_class_actual'], y_test_proba['y_hat_test_proba'])

plt.plot(recall, precision, marker='.', label='Logistic')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('PR curve');

# %%
results = pd.DataFrame(evaluation(y_test_proba,tr,"y_test_class_actual","y_test_class_predicted","y_hat_test_proba",recall,precision), index=[0])
results
# Out:
#    Threshold  Accuracy  Precision    Recall        F1     AUROC      Gini  \
# 0        0.5  0.683365   0.959913  0.684231  0.798959  0.739869  0.479737
#
#       AUCPR
# 0  0.965914

# %% [markdown]
# <div id="eight">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">8. Scorecard Development</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="scorecardcreate">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">8.1 Creating a Scorecard</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
summary_table
# Out:
#                           Feature name  Coefficients
# 0                            Intercept     -0.320272
# 1   NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2                        CODE_GENDER:M     -0.273369
# 3                 EXT_SOURCE_2:missing     -0.185798
# 4                 EXT_SOURCE_2:<=0.171     -0.857951
# ..                                 ...           ...
# 75          LOAN_DURATION:10.148–14.37      0.687648
# 76          LOAN_DURATION:14.37–21.758      0.618108
# 77         LOAN_DURATION:21.758–28.092      0.998825
# 78         LOAN_DURATION:28.092–31.258      0.748501
# 79         LOAN_DURATION:31.258–39.702      0.925086
#
# [80 rows x 2 columns]

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ["Feature name"])
df_ref_categories["Coefficients"] = 0
df_ref_categories
# Out:
#                           Feature name  Coefficients
# 0        NAME_CONTRACT_TYPE:Cash loans             0
# 1                        CODE_GENDER:F             0
# 2                  EXT_SOURCE_2:>0.855             0
# 3                  EXT_SOURCE_3:>0.896             0
# 4                  EXT_SOURCE_1:>0.952             0
# 5                     AGE_IN_YEARS:>69             0
# 6               REGION_RATING_CLIENT:1             0
# 7          DAYS_LAST_PHONE_CHANGE:>0.0             0
# 8                 DAYS_ID_PUBLISH:>0.0             0
# 9              DAYS_EMPLOYED:>365243.0             0
# 10                   FLAG_DOCUMENT_3:1             0
# 11            REG_CITY_NOT_LIVE_CITY:0             0
# 12              DAYS_REGISTRATION:>0.0             0
# 13          AMT_GOODS_PRICE:>2254500.0             0
# 14  REGION_POPULATION_RELATIVE:>0.0725             0
# 15               LOAN_DURATION:>39.702             0

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
df_scorecard.reset_index(inplace = True)
df_scorecard
# Out:
#     index                        Feature name  Coefficients
# 0       0                           Intercept     -0.320272
# 1       1  NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2       2                       CODE_GENDER:M     -0.273369
# 3       3                EXT_SOURCE_2:missing     -0.185798
# 4       4                EXT_SOURCE_2:<=0.171     -0.857951
# ..    ...                                 ...           ...
# 91     11            REG_CITY_NOT_LIVE_CITY:0      0.000000
# 92     12              DAYS_REGISTRATION:>0.0      0.000000
# 93     13          AMT_GOODS_PRICE:>2254500.0      0.000000
# 94     14  REGION_POPULATION_RELATIVE:>0.0725      0.000000
# 95     15               LOAN_DURATION:>39.702      0.000000
#
# [96 rows x 3 columns]

# %%
df_scorecard["Original feature name"] = df_scorecard["Feature name"].str.split(":").str[0]
df_scorecard
# Out:
#     index                        Feature name  Coefficients  \
# 0       0                           Intercept     -0.320272
# 1       1  NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2       2                       CODE_GENDER:M     -0.273369
# 3       3                EXT_SOURCE_2:missing     -0.185798
# 4       4                EXT_SOURCE_2:<=0.171     -0.857951
# ..    ...                                 ...           ...
# 91     11            REG_CITY_NOT_LIVE_CITY:0      0.000000
# 92     12              DAYS_REGISTRATION:>0.0      0.000000
# 93     13          AMT_GOODS_PRICE:>2254500.0      0.000000
# 94     14  REGION_POPULATION_RELATIVE:>0.0725      0.000000
# 95     15               LOAN_DURATION:>39.702      0.000000
#
#          Original feature name
# 0                    Intercept
# 1           NAME_CONTRACT_TYPE
# 2                  CODE_GENDER
# 3                 EXT_SOURCE_2
# 4                 EXT_SOURCE_2
# ..                         ...
# ...

# %%
# Define the min and max threshholds for our scorecard
min_score = 300
max_score = 850

# %%
min_sum_coef = df_scorecard.groupby("Original feature name")["Coefficients"].min().sum()
max_sum_coef = df_scorecard.groupby("Original feature name")["Coefficients"].max().sum()

df_scorecard["Score - Calculation"] = df_scorecard["Coefficients"] * (max_score - min_score) / (max_sum_coef - min_sum_coef)

df_scorecard.loc[0, "Score - Calculation"] = ((df_scorecard.loc[0,"Coefficients"] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score

df_scorecard["Score - Preliminary"] = df_scorecard["Score - Calculation"].round()
df_scorecard
# Out:
#     index                        Feature name  Coefficients  \
# 0       0                           Intercept     -0.320272
# 1       1  NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2       2                       CODE_GENDER:M     -0.273369
# 3       3                EXT_SOURCE_2:missing     -0.185798
# 4       4                EXT_SOURCE_2:<=0.171     -0.857951
# ..    ...                                 ...           ...
# 91     11            REG_CITY_NOT_LIVE_CITY:0      0.000000
# 92     12              DAYS_REGISTRATION:>0.0      0.000000
# 93     13          AMT_GOODS_PRICE:>2254500.0      0.000000
# 94     14  REGION_POPULATION_RELATIVE:>0.0725      0.000000
# 95     15               LOAN_DURATION:>39.702      0.000000
#
#          Original feature name  Score - Calculation  Score - Preliminary
# 0                    Intercept           536.624900                537.0
# 1           NAME_CONTRACT_TYPE            28.038905                 28.0
# ...

# %%
# check the min and max possible scores of our scorecard
min_sum_score_prel = df_scorecard.groupby("Original feature name")["Score - Preliminary"].min().sum()
max_sum_score_prel = df_scorecard.groupby("Original feature name")["Score - Preliminary"].max().sum()
print(min_sum_score_prel)
print(max_sum_score_prel)
# Out:
# 300.0
# 849.0

# %%
df_scorecard["Difference"] = df_scorecard["Score - Preliminary"] - df_scorecard["Score - Calculation"]
df_scorecard
# Out:
#     index                        Feature name  Coefficients  \
# 0       0                           Intercept     -0.320272
# 1       1  NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2       2                       CODE_GENDER:M     -0.273369
# 3       3                EXT_SOURCE_2:missing     -0.185798
# 4       4                EXT_SOURCE_2:<=0.171     -0.857951
# ..    ...                                 ...           ...
# 91     11            REG_CITY_NOT_LIVE_CITY:0      0.000000
# 92     12              DAYS_REGISTRATION:>0.0      0.000000
# 93     13          AMT_GOODS_PRICE:>2254500.0      0.000000
# 94     14  REGION_POPULATION_RELATIVE:>0.0725      0.000000
# 95     15               LOAN_DURATION:>39.702      0.000000
#
#          Original feature name  Score - Calculation  Score - Preliminary  \
# 0                    Intercept           536.624900                537.0
# 1           NAME_CONTRACT_TYPE            28.038905                 28.0
# ...

# %%
df_scorecard["Score - Final"] = df_scorecard["Score - Preliminary"]
df_scorecard.loc[0, "Score - Final"] = 537
df_scorecard
# Out:
#     index                        Feature name  Coefficients  \
# 0       0                           Intercept     -0.320272
# 1       1  NAME_CONTRACT_TYPE:Revolving loans      0.514260
# 2       2                       CODE_GENDER:M     -0.273369
# 3       3                EXT_SOURCE_2:missing     -0.185798
# 4       4                EXT_SOURCE_2:<=0.171     -0.857951
# ..    ...                                 ...           ...
# 91     11            REG_CITY_NOT_LIVE_CITY:0      0.000000
# 92     12              DAYS_REGISTRATION:>0.0      0.000000
# 93     13          AMT_GOODS_PRICE:>2254500.0      0.000000
# 94     14  REGION_POPULATION_RELATIVE:>0.0725      0.000000
# 95     15               LOAN_DURATION:>39.702      0.000000
#
#          Original feature name  Score - Calculation  Score - Preliminary  \
# 0                    Intercept           536.624900                537.0
# 1           NAME_CONTRACT_TYPE            28.038905                 28.0
# ...

# %%
# Recheck min and max possible scores
print(df_scorecard.groupby("Original feature name")["Score - Final"].min().sum())
print(df_scorecard.groupby("Original feature name")["Score - Final"].max().sum())
# Out:
# 300.0
# 849.0

# %%
df_scorecard.to_csv("scorecard.csv", index=False)

# %% [markdown]
# <div id="calcreditscores">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">8.2 Calculating credit scores in the X_test set</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_test_woe_transformed = woe_transform.fit_transform(X_test)

X_test_woe_transformed.insert(0, "Intercept", 1)
X_test_woe_transformed.head()
# Out:
#         Intercept  NAME_CONTRACT_TYPE:Revolving loans  CODE_GENDER:M  \
# 245895          1                                   0              1
# 98194           1                                   0              0
# 36463           1                                   0              0
# 249923          1                                   0              0
# 158389          1                                   0              1
#
#         EXT_SOURCE_2:missing  EXT_SOURCE_2:<=0.171  EXT_SOURCE_2:0.171–0.285  \
# 245895                     0                     0                         0
# 98194                      0                     0                         0
# 36463                      0                     0                         0
# 249923                     0                     0                         0
# 158389                     0                     0                         0
#
#         EXT_SOURCE_2:0.285–0.399  EXT_SOURCE_2:0.399–0.513  \
# ...

# %%
scorecard_scores = df_scorecard["Score - Final"]

print(X_test_woe_transformed.shape)
print(scorecard_scores.shape)
# Out:
# (61503, 80)
# (96,)

# %%
# we can see that the test set has less columns than the rows in scorecard due to the reference categories
# since the reference categories will always be scored as 0 based on the scorecard, it is safe to add ...
# these categories to the end of test set with 0 values
X_test_woe_transformed = pd.concat([X_test_woe_transformed, pd.DataFrame(dict.fromkeys(ref_categories, [0] * len(X_test_woe_transformed)), 
                                                                         index = X_test_woe_transformed.index)], axis = 1)

scorecard_scores = scorecard_scores.values.reshape(96, 1)
print(X_test_woe_transformed.shape)
print(scorecard_scores.shape)
# Out:
# (61503, 96)
# (96, 1)

# %%
y_scores = X_test_woe_transformed.dot(scorecard_scores)
y_scores.head()
# Out:
#             0
# 245895  539.0
# 98194   593.0
# 36463   543.0
# 249923  647.0
# 158389  589.0

# %% [markdown]
# <div id="loancutoffs">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">8.3 Setting loan approval cut-offs</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
J = tpr - fpr

ix = np.argmax(J)
best_thresh = thresholds[ix]
print("Best Threshold: %f" % (best_thresh))
# Out:
# Best Threshold: 0.234342

# %% [markdown]
# This means that based on the Youden's J statistic, the ideal probability threshold is **0.234** which minimizes the FPR and maximimizes the TPR. All samples with a predicted probability **higher** than this should be classified as **non-defaulters**, and vice versa. At first, this ideal threshold appears to be counterintuitive compared to the default probability threshold of 0.5. But remember that we used the class_weight parameter when fitting our logistic regression model that would have helped us.
#
# We can confirm this by looking at our original confusion matrix with the updated threshold.

# %%
tr = best_thresh

y_test_proba["y_test_class_predicted"] = np.where(y_test_proba["y_hat_test_proba"] > tr, 1, 0)
cm = metrics.confusion_matrix(y_test_proba["y_test_class_actual"], y_test_proba["y_test_class_predicted"], normalize = "all")
True_Pos, True_Neg, False_Pos, False_Neg = confusion_matrix_mod(cm)

# %%
precision, recall, thresholds = metrics.precision_recall_curve(y_test_proba["y_test_class_actual"], y_test_proba["y_hat_test_proba"])

results = pd.DataFrame(evaluation(y_test_proba,tr,"y_test_class_actual","y_test_class_predicted","y_hat_test_proba",recall,precision), index=[0])
results
# Out:
#    Threshold  Accuracy  Precision    Recall        F1     AUROC      Gini  \
# 0   0.234342  0.897485   0.932577  0.957757  0.944999  0.739869  0.479737
#
#       AUCPR
# 0  0.965914

# %% [markdown]
# Now, let us find the corresponding acceptance and rejection rates on the test set at this ideal threshold

# %%
df_cutoffs = pd.DataFrame(thresholds, columns = ["thresholds"])

df_cutoffs["Score"] = ((np.log(df_cutoffs["thresholds"] / (1 - df_cutoffs["thresholds"])) - min_sum_coef) * 
                       ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
df_cutoffs.head()
# Out:
#    thresholds  Score
# 0    0.044473  387.0
# 1    0.044566  387.0
# 2    0.046953  390.0
# 3    0.049873  393.0
# 4    0.050956  395.0

# %%
def n_approved(p):
    """We define a function called 'n_approved' which assigns a value of 1 if a predicted probability 
    is greater than the parameter p, which is a threshold, and a value of 0, if it is not."""
    return np.where(y_test_proba['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs["N Approved"] = df_cutoffs["thresholds"].apply(n_approved)
df_cutoffs["N Rejected"] = y_test_proba["y_hat_test_proba"].shape[0] - df_cutoffs["N Approved"]

df_cutoffs["Approval Rate"] = df_cutoffs["N Approved"] / y_test_proba["y_hat_test_proba"].shape[0]
df_cutoffs["Rejection Rate"] = 1 - df_cutoffs["Approval Rate"]

df_cutoffs.head()
# Out:
#    thresholds  Score  N Approved  N Rejected  Approval Rate  Rejection Rate
# 0    0.044473  387.0       61503           0       1.000000        0.000000
# 1    0.044566  387.0       61502           1       0.999984        0.000016
# 2    0.046953  390.0       61501           2       0.999967        0.000033
# 3    0.049873  393.0       61500           3       0.999951        0.000049
# 4    0.050956  395.0       61499           4       0.999935        0.000065

# %%
# let's have a look at the approval and rejection rates at our best threshold
df_cutoffs[df_cutoffs["thresholds"].between(0.234, 0.235)]
# Out:
#       thresholds  Score  N Approved  N Rejected  Approval Rate  Rejection Rate
# 3408    0.234011  489.0       58092        3411       0.944539        0.055461
# 3409    0.234119  489.0       58091        3412       0.944523        0.055477
# 3410    0.234148  489.0       58090        3413       0.944507        0.055493
# 3411    0.234154  489.0       58089        3414       0.944491        0.055509
# 3412    0.234159  489.0       58088        3415       0.944474        0.055526
# 3413    0.234187  489.0       58087        3416       0.944458        0.055542
# 3414    0.234222  489.0       58086        3417       0.944442        0.055558
# 3415    0.234288  490.0       58085        3418       0.944425        0.055575
# 3416    0.234298  490.0       58084        3419       0.944409        0.055591
# 3417    0.234337  490.0       58083        3420       0.944393        0.055607
# 3418    0.234342  490.0       58082        3421       0.944377        0.055623
# ...

# %%
# compare the above rates with the case of the default 0.5 threshold
df_cutoffs[df_cutoffs["thresholds"].between(0.5, 0.5001)]
# Out:
#        thresholds  Score  N Approved  N Rejected  Approval Rate  \
# 21145    0.500000  554.0       40312       21191       0.655448
# 21146    0.500011  554.0       40311       21192       0.655431
# 21147    0.500035  554.0       40310       21193       0.655415
# 21148    0.500037  554.0       40309       21194       0.655399
# 21149    0.500048  554.0       40308       21195       0.655383
# 21150    0.500072  554.0       40307       21196       0.655366
# 21151    0.500092  554.0       40306       21197       0.655350
# 21152    0.500096  554.0       40305       21198       0.655334
#
#        Rejection Rate
# 21145        0.344552
# 21146        0.344569
# 21147        0.344585
# 21148        0.344601
# 21149        0.344617
# 21150        0.344634
# 21151        0.344650
# 21152        0.344666

# %% [markdown]
# 0.5 threshold would result in a very high rejection rate with a corresponding loss of business.
#
# Accordingly, we will stick with our ideal threshold and the corresponding Credit Score of 490, and will monitor the model's performance in production

# %% [markdown]
# <div id="calcreditscorestest">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">8.4 Calculating credit scores in the X_test set with the best threshold</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
y_scores = X_test_woe_transformed.dot(scorecard_scores)
print(y_scores.shape, X_test.shape, IDs_test.shape)

y_scores = y_scores.rename(columns={0: "Test Sets' Score"})
y_scores.insert(0, "SK_ID_CURR", IDs_test)
y_scores.insert(2, "AMT_CREDIT", CREDIT_test)
y_scores.reset_index(inplace=True, drop=True)
y_scores.head()
# Out:
# (61503, 1) (61503, 35) (61503,)
#    SK_ID_CURR  Test Sets' Score  AMT_CREDIT
# 0      384575             539.0    465457.5
# 1      214010             593.0   1281712.5
# 2      142232             543.0    495000.0
# 3      389171             647.0    254700.0
# 4      283617             589.0    308133.0

# %%
threshold = best_thresh
X_test_length = len(X_test)

thresholds = [threshold] * X_test_length
df_cutoffs_test = pd.DataFrame(thresholds, columns=["Thresholds"])

df_cutoffs_test["Thresholds' Score"] = ((np.log(df_cutoffs_test["Thresholds"] / (1 - df_cutoffs_test["Thresholds"])) - min_sum_coef) * 
                       ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
df_cutoffs_test.head()
# Out:
#    Thresholds  Thresholds' Score
# 0    0.234342              490.0
# 1    0.234342              490.0
# 2    0.234342              490.0
# 3    0.234342              490.0
# 4    0.234342              490.0

# %%
y_hat_test_proba = pipeline.predict_proba(X_test)
y_hat_test_proba = y_hat_test_proba[:][: , 1]

# %%
y_test_proba = pd.DataFrame(y_hat_test_proba)

# %%
y_test_proba.columns = ["y prob. prediction"]
y_test_proba.head()
# Out:
#    y prob. prediction
# 0            0.434046
# 1            0.662437
# 2            0.448671
# 3            0.849081
# 4            0.651030

# %%
y_test_proba["Loan Status"] = y_test_proba["y prob. prediction"] \
                              .apply(lambda x: "Rejected" if x < threshold else "Accepted")

# %%
y_test_proba.head()
# Out:
#    y prob. prediction Loan Status
# 0            0.434046    Accepted
# 1            0.662437    Accepted
# 2            0.448671    Accepted
# 3            0.849081    Accepted
# 4            0.651030    Accepted

# %%
final_table = pd.concat([y_scores,y_test_proba,df_cutoffs_test], axis = 1)
desired_column_order = ["SK_ID_CURR", "Thresholds", "y prob. prediction",
                        "Thresholds' Score", "Test Sets' Score", "AMT_CREDIT", "Loan Status"]
final_table = final_table.reindex(columns=desired_column_order)

# %%
final_table.sample(20)
# Out:
#        SK_ID_CURR  Thresholds  y prob. prediction  Thresholds' Score  \
# 49895      419431    0.234342            0.438467              490.0
# 22489      173832    0.234342            0.702864              490.0
# 12582      340512    0.234342            0.373203              490.0
# 26617      235520    0.234342            0.729706              490.0
# 45783      217879    0.234342            0.509629              490.0
# 21296      377056    0.234342            0.372890              490.0
# 54074      246858    0.234342            0.656046              490.0
# 51510      146950    0.234342            0.819870              490.0
# 32716      139590    0.234342            0.256757              490.0
# 46050      349034    0.234342            0.872696              490.0
# 47680      351334    0.234342            0.597184              490.0
# 51110      110388    0.234342            0.251157              490.0
# 59086      433497    0.234342            0.405830              490.0
# ...

# %%
total_accepted = len(final_table[final_table["Loan Status"] == "Accepted"])
total_rejected = len(final_table[final_table["Loan Status"] == "Rejected"])

acceptance_rate = total_accepted / len(final_table)
rejection_rate = total_rejected / len(final_table)

money_saved = (final_table["AMT_CREDIT"]*((final_table["Loan Status"] == "Accepted").astype(int))).sum()*(True_Pos+True_Neg)
money_losses = (final_table["AMT_CREDIT"]*((final_table["Loan Status"] == "Rejected").astype(int))).sum()*(False_Pos+False_Neg)

results = pd.DataFrame({"Total Applicants": [total_accepted+total_rejected],
                        "Total Accepted": [total_accepted],
                        "Total Rejected": [total_rejected],
                        "Acceptance Rate": "{:.2f}%".format(acceptance_rate*100),
                        "Rejection Rate": "{:.2f}%".format(rejection_rate*100),
                        "TP+TN": "{:.2f}%".format((True_Pos+True_Neg)*100),
                        "FP+FN": "{:.2f}%".format((False_Pos+False_Neg)*100),
                        "Money Saved (IDR)": "{:.2e}".format(money_saved),
                        "Money Losses (IDR)": "{:.2e}".format(money_losses)})
results
# Out:
#    Total Applicants  Total Accepted  Total Rejected Acceptance Rate  \
# 0             61503           58082            3421          94.44%
#
#   Rejection Rate   TP+TN   FP+FN Money Saved (IDR) Money Losses (IDR)
# 0          5.56%  89.75%  10.25%          3.14e+10           1.72e+08

# %% [markdown]
# * True Positive (TP): If my machine predicts that the applicant will not default, and they actually do not default.
# * True Negative (TN): If my machine predicts that the applicant will default, and they actually do default.
# * False Positive (FP): If my machine predicts that the applicant will not default, but they actually do default.
# * False Negative (FN): If my machine predicts that the applicant will default, but they actually do not default.

# %% [markdown]
# So, the company will save approximately 30,000,000,000 IDR and will lose approximately 100,000,000 IDR.
#
# These variables depend on the quality of metrics from my machine learning model, such as threshold, accuracy, precision, recall, F1 score, AUROC, Gini, and AUCPR. The results of this project are threshold = 0.23, accuracy = 0.90, precision = 0.93, recall = 0.96, F1 = 0.94, AUROC = 0.74, Gini = 0.48, and AUCPR = 0.97. These metrics exhibit strong performance in credit risk modeling. Nevertheless, we can enhance them further by incorporating features with higher information value (IV). Several CSV files encompassing such features possess significant IV potential, yet I was unable to merge them into the application_train.csv and application_test.csv datasets. These files comprise:
#
# * bureau.csv
# * bureau_balance.csv
# * credit_card_balance.csv
# * installments_payments.csv
# * POS_CASH_balance.csv
# * previous_application.csv
#
# In the future, I aspire to acquire a more advanced laptop or computer that can effortlessly handle the merging of these files. Presently, my laptop, equipped with only 4GB of RAM, frequently crashes during the attempt.

# %%
final_table.to_csv("test_submission.csv", index=False)

# %% [markdown]
# <div id="testsubmncalcredscores">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">8.5 Calculating credit scores in the test_subm set with the best threshold</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
test_subm_woe_transformed = woe_transform.fit_transform(test_subm)

test_subm_woe_transformed.insert(0, 'Intercept', 1)
test_subm_woe_transformed.head()
# Out:
#    Intercept  NAME_CONTRACT_TYPE:Revolving loans  CODE_GENDER:M  \
# 0          1                                   0              0
# 1          1                                   0              1
# 2          1                                   0              1
# 3          1                                   0              0
# 4          1                                   0              1
#
#    EXT_SOURCE_2:missing  EXT_SOURCE_2:<=0.171  EXT_SOURCE_2:0.171–0.285  \
# 0                     0                     0                         0
# 1                     0                     0                         0
# 2                     0                     0                         0
# 3                     0                     0                         0
# 4                     0                     0                         0
#
#    EXT_SOURCE_2:0.285–0.399  EXT_SOURCE_2:0.399–0.513  \
# 0                         0                         0
# ...

# %%
scorecard_scores = df_scorecard['Score - Final']

print(test_subm_woe_transformed.shape)
print(scorecard_scores.shape)
# Out:
# (48744, 80)
# (96,)

# %%
test_subm_woe_transformed = pd.concat([test_subm_woe_transformed, pd.DataFrame(dict.fromkeys(ref_categories, [0] * len(test_subm_woe_transformed)), 
                                                                         index = test_subm_woe_transformed.index)], axis = 1)

scorecard_scores = scorecard_scores.values.reshape(96, 1)
print(test_subm_woe_transformed.shape)
print(scorecard_scores.shape)
# Out:
# (48744, 96)
# (96, 1)

# %%
y_scores = test_subm_woe_transformed.dot(scorecard_scores)
print(y_scores.shape, test_subm.shape, IDs_test_subm.shape)

y_scores = y_scores.rename(columns={0: "Test Sets' Score"})
y_scores.insert(0, "SK_ID_CURR", IDs_test_subm)
y_scores.insert(2, "AMT_CREDIT", CREDIT_test_subm)
y_scores.head()
# Out:
# (48744, 1) (48744, 35) (48744,)
#    SK_ID_CURR  Test Sets' Score  AMT_CREDIT
# 0      100001             567.0    568800.0
# 1      100005             525.0    222768.0
# 2      100013             632.0    663264.0
# 3      100028             618.0   1575000.0
# 4      100038             517.0    625500.0

# %%
threshold = best_thresh
test_subm_length = len(test_subm)

thresholds = [threshold] * test_subm_length
df_cutoffs_test = pd.DataFrame(thresholds, columns=["Thresholds"])

df_cutoffs_test["Thresholds' Score"] = ((np.log(df_cutoffs_test["Thresholds"] / (1 - df_cutoffs_test["Thresholds"])) - min_sum_coef) * 
                       ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
df_cutoffs_test.head()
# Out:
#    Thresholds  Thresholds' Score
# 0    0.234342              490.0
# 1    0.234342              490.0
# 2    0.234342              490.0
# 3    0.234342              490.0
# 4    0.234342              490.0

# %%
y_hat_test_proba = pipeline.predict_proba(test_subm)
y_hat_test_proba = y_hat_test_proba[:][: , 1]

# %%
y_test_proba = pd.DataFrame(y_hat_test_proba)

# %%
y_test_proba.columns = ["y prob. prediction"]
y_test_proba.head()
# Out:
#    y prob. prediction
# 0            0.564588
# 1            0.372707
# 2            0.803451
# 3            0.760223
# 4            0.331255

# %%
y_test_proba["Loan Status"] = y_test_proba["y prob. prediction"] \
                              .apply(lambda x: "Rejected" if x < threshold else "Accepted")

# %%
y_test_proba.head()
# Out:
#    y prob. prediction Loan Status
# 0            0.564588    Accepted
# 1            0.372707    Accepted
# 2            0.803451    Accepted
# 3            0.760223    Accepted
# 4            0.331255    Accepted

# %%
final_table = pd.concat([y_scores,y_test_proba,df_cutoffs_test], axis = 1)
desired_column_order = ["SK_ID_CURR", "Thresholds", "y prob. prediction",
                        "Thresholds' Score", "Test Sets' Score", "AMT_CREDIT", "Loan Status"]
final_table = final_table.reindex(columns=desired_column_order)

# %%
final_table.sample(20)
# Out:
#        SK_ID_CURR  Thresholds  y prob. prediction  Thresholds' Score  \
# 28254      306121    0.234342            0.716750              490.0
# 4914       135523    0.234342            0.181363              490.0
# 38087      379301    0.234342            0.761569              490.0
# 19137      239058    0.234342            0.646401              490.0
# 42012      407555    0.234342            0.600206              490.0
# 7952       158352    0.234342            0.831725              490.0
# 43196      414372    0.234342            0.524869              490.0
# 45307      431756    0.234342            0.628840              490.0
# 41861      406841    0.234342            0.743021              490.0
# 21332      254835    0.234342            0.803265              490.0
# 12759      192876    0.234342            0.508556              490.0
# 40337      396952    0.234342            0.223500              490.0
# 33707      345924    0.234342            0.836324              490.0
# ...

# %%
total_accepted = len(final_table[final_table["Loan Status"] == "Accepted"])
total_rejected = len(final_table[final_table["Loan Status"] == "Rejected"])

acceptance_rate = total_accepted / len(final_table)
rejection_rate = total_rejected / len(final_table)

results = pd.DataFrame({"Total Applicants": [total_accepted+total_rejected],
                        "Total Accepted": [total_accepted],
                        "Total Rejected": [total_rejected],
                        "Acceptance Rate": "{:.2f}%".format(acceptance_rate*100),
                        "Rejection Rate": "{:.2f}%".format(rejection_rate*100)})
results
# Out:
#    Total Applicants  Total Accepted  Total Rejected Acceptance Rate  \
# 0             48744           46048            2696          94.47%
#
#   Rejection Rate
# 0          5.53%

# %%
final_table.to_csv("test_subm_submission.csv", index=False)

# %% [markdown]
# ## References
#
# * https://github.com/jihadakbr/credit-risk-modeling
# * https://towardsdatascience.com/how-to-develop-a-credit-risk-model-and-scorecard-91335fc01f03
# * https://www.kaggle.com/code/chandrimad31/credit-risk-part-1-binning-woe-iv-pd-model
# * https://www.listendata.com/2015/03/weight-of-evidence-woe-and-information.html
# * https://www.analyticsvidhya.com/blog/2021/06/understand-weight-of-evidence-and-information-value/
# * https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/
# * https://medium.com/mlearning-ai/weight-of-evidence-woe-and-information-value-iv-how-to-use-it-in-eda-and-model-building-3b3b98efe0e8
